# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import Input, Dense, BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):    
    """
    Build your own model
    """
    input_layer = Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
learning_rate = 1e-2
epochs = 50
batch_size = 256

# %%
# 載入 Callbacks
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix

# Record_fp_tp
class Record_tp_tn(Callback):
    """Define a callback function to collect tp/tn, named Record_fp_tp.
    
    """
    def on_train_begin(self, epoch, logs={}):
        logs = logs or {}
        record_items = ["val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs={}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        CM = confusion_matrix(y_true, y_pred)
        logs['val_tp'] = CM[1][1]
        logs['val_tn'] = CM[0][0]
            
rec_tptn = Record_tp_tn()

# %%
keras.backend.clear_session() # 把舊的 Graph 清掉
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(factor=0.2, min_lr=1e-12, monitor='val_loss', patience=2, verbose=1)
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=learning_rate, nesterov=True, momentum=0.95)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
"""
To do:
Fit the model with rec_tptn callback_fn
"""
model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), shuffle=True, 
          callbacks=[earlystop, reduce_lr, rec_tptn])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""
To do:
Collect tp/tn from model history
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 8s 157us/step - loss: 1.6816 - accuracy: 0.4075 - val_loss: 1.6379 - val_accuracy: 0.4148
# Epoch 2/50
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.4453 - accuracy: 0.4891 - val_loss: 1.8488 - val_accuracy: 0.3645
# Epoch 3/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.3485 - accuracy: 0.5210 - val_loss: 1.6270 - val_accuracy: 0.4221
# Epoch 4/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.2794 - accuracy: 0.5474 - val_loss: 1.6404 - val_accuracy: 0.4233
# Epoch 5/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.2223 - accuracy: 0.5694 - val_loss: 1.5157 - val_accuracy: 0.4704
# Epoch 6/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.1762 - accuracy: 0.5816 - val_loss: 1.5320 - val_accuracy: 0.4694
# Epoch 7/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.1304 - accuracy: 0.5993 - val_loss: 1.7867 - val_accuracy: 0.3978
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 8/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.0311 - accuracy: 0.6363 - val_loss: 1.3955 - val_accuracy: 0.5151
# Epoch 9/50
# 50000/50000 [==============================] - 4s 78us/step - loss: 0.9511 - accuracy: 0.6669 - val_loss: 1.3193 - val_accuracy: 0.5449
# Epoch 10/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.9194 - accuracy: 0.6790 - val_loss: 1.3129 - val_accuracy: 0.5460
# Epoch 11/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 0.8934 - accuracy: 0.6871 - val_loss: 1.3626 - val_accuracy: 0.5338
# Epoch 12/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 0.8679 - accuracy: 0.6944 - val_loss: 1.3774 - val_accuracy: 0.5317
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 13/50
# 50000/50000 [==============================] - 4s 70us/step - loss: 0.8193 - accuracy: 0.7173 - val_loss: 1.3159 - val_accuracy: 0.5492
# Epoch 14/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 0.7977 - accuracy: 0.7265 - val_loss: 1.3211 - val_accuracy: 0.5520
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Epoch 15/50
# 50000/50000 [==============================] - 4s 77us/step - loss: 0.7801 - accuracy: 0.7333 - val_loss: 1.3195 - val_accuracy: 0.5502
# Epoch 16/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.7770 - accuracy: 0.7357 - val_loss: 1.3208 - val_accuracy: 0.5505
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# Epoch 17/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 0.7755 - accuracy: 0.7348 - val_loss: 1.3211 - val_accuracy: 0.5504
# Epoch 18/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.7736 - accuracy: 0.7369 - val_loss: 1.3214 - val_accuracy: 0.5497
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# Epoch 19/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 0.7728 - accuracy: 0.7355 - val_loss: 1.3215 - val_accuracy: 0.5503
# Epoch 20/50
# 50000/50000 [==============================] - 4s 70us/step - loss: 0.7723 - accuracy: 0.7354 - val_loss: 1.3215 - val_accuracy: 0.5505
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# Epoch 21/50
# 50000/50000 [==============================] - 4s 70us/step - loss: 0.7705 - accuracy: 0.7371 - val_loss: 1.3214 - val_accuracy: 0.5500
# Epoch 22/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.7719 - accuracy: 0.7382 - val_loss: 1.3213 - val_accuracy: 0.5507
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.2799998785339995e-07.
# Epoch 23/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 0.7709 - accuracy: 0.7361 - val_loss: 1.3215 - val_accuracy: 0.5497
# Epoch 24/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.7714 - accuracy: 0.7367 - val_loss: 1.3215 - val_accuracy: 0.5497
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.5599996433811613e-08.
# Epoch 25/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.7712 - accuracy: 0.7364 - val_loss: 1.3211 - val_accuracy: 0.5506
# Epoch 26/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.7722 - accuracy: 0.7367 - val_loss: 1.3217 - val_accuracy: 0.5501
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 5.1199993578165965e-09.
# Epoch 27/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.7729 - accuracy: 0.7367 - val_loss: 1.3215 - val_accuracy: 0.5499
# Epoch 28/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.7726 - accuracy: 0.7358 - val_loss: 1.3213 - val_accuracy: 0.5497
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.023999907090456e-09.
# Epoch 29/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.7720 - accuracy: 0.7362 - val_loss: 1.3216 - val_accuracy: 0.5504
# Epoch 30/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.7735 - accuracy: 0.7358 - val_loss: 1.3216 - val_accuracy: 0.5500
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 2.0479997697719911e-10.
# Epoch 31/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.7717 - accuracy: 0.7366 - val_loss: 1.3216 - val_accuracy: 0.5501
# Epoch 32/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.7713 - accuracy: 0.7355 - val_loss: 1.3219 - val_accuracy: 0.5504
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.095999650566285e-11.
# Epoch 33/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.7717 - accuracy: 0.7367 - val_loss: 1.3216 - val_accuracy: 0.5500
# Epoch 34/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.7702 - accuracy: 0.7379 - val_loss: 1.3217 - val_accuracy: 0.5499
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 8.19199916235469e-12.
# Epoch 35/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 0.7705 - accuracy: 0.7369 - val_loss: 1.3215 - val_accuracy: 0.5501
# Epoch 36/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.7714 - accuracy: 0.7380 - val_loss: 1.3218 - val_accuracy: 0.5510
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.6383998324709382e-12.
# Epoch 37/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.7724 - accuracy: 0.7362 - val_loss: 1.3215 - val_accuracy: 0.5507
# Epoch 38/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.7725 - accuracy: 0.7367 - val_loss: 1.3214 - val_accuracy: 0.5503
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1e-12.
# Epoch 39/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.7733 - accuracy: 0.7363 - val_loss: 1.3214 - val_accuracy: 0.5496
# Epoch 40/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.7732 - accuracy: 0.7359 - val_loss: 1.3216 - val_accuracy: 0.5504
# Epoch 41/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.7728 - accuracy: 0.7378 - val_loss: 1.3219 - val_accuracy: 0.5502
# Epoch 42/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.7701 - accuracy: 0.7374 - val_loss: 1.3217 - val_accuracy: 0.5500
# Epoch 43/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.7709 - accuracy: 0.7388 - val_loss: 1.3217 - val_accuracy: 0.5500
# Epoch 44/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 0.7717 - accuracy: 0.7361 - val_loss: 1.3216 - val_accuracy: 0.5501
# Epoch 45/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.7711 - accuracy: 0.7359 - val_loss: 1.3215 - val_accuracy: 0.5499
# Epoch 46/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.7719 - accuracy: 0.7367 - val_loss: 1.3215 - val_accuracy: 0.5509
# Epoch 47/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.7717 - accuracy: 0.7361 - val_loss: 1.3216 - val_accuracy: 0.5502
# Epoch 48/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.7712 - accuracy: 0.7375 - val_loss: 1.3217 - val_accuracy: 0.5507
# Epoch 49/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.7730 - accuracy: 0.7363 - val_loss: 1.3215 - val_accuracy: 0.5504
# Epoch 50/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.7713 - accuracy: 0.7360 - val_loss: 1.3214 - val_accuracy: 0.5508
# Epoch 00050: early stopping

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
