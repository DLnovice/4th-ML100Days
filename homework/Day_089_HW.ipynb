# %% [markdown]
# ## Work
# 1. 請自行定義一個 loss function, 為 0.3 * focal loss + 0.7 cross-entropy，訓練並比較結果

# %%
import os
import keras
import matplotlib.pyplot as plt
# %matplotlib inline

train, test = keras.datasets.cifar10.load_data()

## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import Input, Dense, BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):    
    """
    Build your own model
    """
    input_layer = Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
learning_rate = 1e-2
epochs = 50
batch_size = 256

# %%
import tensorflow as tf
import keras.backend as K
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

"""
TO DO:
Write your combined loss
"""
def combined_loss(gamma=2., alpha=4., ce_weights=0.7, fcl_weights=0.3):
    """Define the customized loss."""
    gamma = float(gamma)
    alpha = float(alpha)
    def ce_focal_loss(y_true, y_pred):
        """Focal loss for multi-classification
        FL(p_t)=-alpha(1-p_t)^{gamma}ln(p_t)
        """
        epsilon = 1e-8
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)

        model_out = tf.add(y_pred, epsilon)
        ce = tf.multiply(y_true, -tf.math.log(model_out))
        weight = tf.multiply(y_true, tf.pow(tf.subtract(1., model_out), gamma))
        fl = tf.multiply(alpha, tf.multiply(weight, ce))
        reduced_fl = tf.reduce_max(fl, axis=1)
        
        ce_loss = keras.losses.categorical_crossentropy(y_true, y_pred)
        return fcl_weights * tf.reduce_mean(reduced_fl) + ce_weights * ce_loss
    return ce_focal_loss

ce_weights_list = [0.0, 0.3, 0.5, 0.7, 1]

# %%
results = {}
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(factor=0.2, min_lr=1e-12, monitor='val_loss', patience=2, verbose=1)
for i, ce_w in enumerate(ce_weights_list):
    print(f'ce_weights = {ce_w}, fcl_weights = {1-ce_w}')

    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=learning_rate, nesterov=True, momentum=0.95)
    model.compile(loss=combined_loss(ce_weights=ce_w, fcl_weights=1-ce_w), metrics=["accuracy"], optimizer=optimizer)
    """
    TO DO:
    Compile your model with customized loss
    """

    model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), shuffle=True, 
              callbacks=[earlystop, reduce_lr])
    
    # Collect results
    name_tag = f'ce_weights = {ce_w}, fcl_weights = {1-ce_w}'
    results[name_tag] = {'train-loss': model.history.history["loss"], 'valid-loss': model.history.history["val_loss"], 
                         'train-acc': model.history.history["accuracy"], 'valid-acc': model.history.history["val_accuracy"]}
# Out:
# ce_weights = 0.0, fcl_weights = 1.0
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 6s 112us/step - loss: 4.8836 - accuracy: 0.3889 - val_loss: 5.4670 - val_accuracy: 0.3586
# Epoch 2/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 4.1347 - accuracy: 0.4531 - val_loss: 4.6823 - val_accuracy: 0.3995
# Epoch 3/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 3.8295 - accuracy: 0.4838 - val_loss: 4.1757 - val_accuracy: 0.4544
# Epoch 4/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 3.6009 - accuracy: 0.5081 - val_loss: 4.2300 - val_accuracy: 0.4532
# Epoch 5/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 3.4149 - accuracy: 0.5231 - val_loss: 4.7331 - val_accuracy: 0.4272
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 6/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 3.0811 - accuracy: 0.5618 - val_loss: 3.5388 - val_accuracy: 0.5218
# Epoch 7/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 2.8704 - accuracy: 0.5843 - val_loss: 3.5477 - val_accuracy: 0.5193
# Epoch 8/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 2.7817 - accuracy: 0.5927 - val_loss: 3.5887 - val_accuracy: 0.5140
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 9/50
# 50000/50000 [==============================] - 4s 72us/step - loss: 2.6459 - accuracy: 0.6074 - val_loss: 3.3631 - val_accuracy: 0.5455
# Epoch 10/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 2.5883 - accuracy: 0.6153 - val_loss: 3.3715 - val_accuracy: 0.5392
# Epoch 11/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 2.5646 - accuracy: 0.6182 - val_loss: 3.3815 - val_accuracy: 0.5428
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Epoch 12/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 2.5166 - accuracy: 0.6240 - val_loss: 3.3496 - val_accuracy: 0.5446
# Epoch 13/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 2.5110 - accuracy: 0.6259 - val_loss: 3.3524 - val_accuracy: 0.5443
# Epoch 14/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 2.4979 - accuracy: 0.6258 - val_loss: 3.3569 - val_accuracy: 0.5421
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# Epoch 15/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 2.4970 - accuracy: 0.6256 - val_loss: 3.3544 - val_accuracy: 0.5441
# Epoch 16/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 2.4944 - accuracy: 0.6274 - val_loss: 3.3547 - val_accuracy: 0.5436
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# Epoch 17/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 2.4929 - accuracy: 0.6277 - val_loss: 3.3549 - val_accuracy: 0.5446
# Epoch 18/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 2.4930 - accuracy: 0.6258 - val_loss: 3.3557 - val_accuracy: 0.5441
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# Epoch 19/50
# 50000/50000 [==============================] - 4s 70us/step - loss: 2.4923 - accuracy: 0.6268 - val_loss: 3.3544 - val_accuracy: 0.5445
# Epoch 20/50
# 50000/50000 [==============================] - 4s 72us/step - loss: 2.4934 - accuracy: 0.6265 - val_loss: 3.3550 - val_accuracy: 0.5445
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.2799998785339995e-07.
# Epoch 21/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 2.4994 - accuracy: 0.6266 - val_loss: 3.3547 - val_accuracy: 0.5440
# Epoch 22/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 2.4925 - accuracy: 0.6266 - val_loss: 3.3550 - val_accuracy: 0.5436
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 2.5599996433811613e-08.
# Epoch 00022: early stopping
# ce_weights = 0.3, fcl_weights = 0.7
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 3.9555 - accuracy: 0.3867 - val_loss: 3.8534 - val_accuracy: 0.3869
# Epoch 2/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 3.3615 - accuracy: 0.4538 - val_loss: 4.3085 - val_accuracy: 0.3553
# Epoch 3/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 3.1235 - accuracy: 0.4850 - val_loss: 3.5797 - val_accuracy: 0.4209
# Epoch 4/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 2.9316 - accuracy: 0.5091 - val_loss: 3.8288 - val_accuracy: 0.3943
# Epoch 5/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 2.7977 - accuracy: 0.5268 - val_loss: 3.7984 - val_accuracy: 0.4092
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 6/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 2.5399 - accuracy: 0.5625 - val_loss: 2.9449 - val_accuracy: 0.5097
# Epoch 7/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 2.3551 - accuracy: 0.5872 - val_loss: 2.9723 - val_accuracy: 0.5082
# Epoch 8/50
# 50000/50000 [==============================] - 4s 72us/step - loss: 2.2921 - accuracy: 0.5963 - val_loss: 2.8263 - val_accuracy: 0.5291
# Epoch 9/50
# 50000/50000 [==============================] - 4s 72us/step - loss: 2.2282 - accuracy: 0.6052 - val_loss: 2.9262 - val_accuracy: 0.5156
# Epoch 10/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 2.1679 - accuracy: 0.6122 - val_loss: 2.9053 - val_accuracy: 0.5226
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 11/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 2.0592 - accuracy: 0.6289 - val_loss: 2.7518 - val_accuracy: 0.5414
# Epoch 12/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 2.0029 - accuracy: 0.6402 - val_loss: 2.7524 - val_accuracy: 0.5428
# Epoch 13/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.9763 - accuracy: 0.6428 - val_loss: 2.7585 - val_accuracy: 0.5441
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Epoch 14/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.9445 - accuracy: 0.6463 - val_loss: 2.7378 - val_accuracy: 0.5459
# Epoch 15/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.9319 - accuracy: 0.6481 - val_loss: 2.7392 - val_accuracy: 0.5480
# Epoch 16/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.9249 - accuracy: 0.6504 - val_loss: 2.7373 - val_accuracy: 0.5474
# Epoch 17/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.9231 - accuracy: 0.6509 - val_loss: 2.7404 - val_accuracy: 0.5473
# Epoch 18/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.9210 - accuracy: 0.6495 - val_loss: 2.7397 - val_accuracy: 0.5458
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# Epoch 19/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.9071 - accuracy: 0.6521 - val_loss: 2.7393 - val_accuracy: 0.5467
# Epoch 20/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.9035 - accuracy: 0.6513 - val_loss: 2.7391 - val_accuracy: 0.5469
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# Epoch 21/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.9039 - accuracy: 0.6529 - val_loss: 2.7392 - val_accuracy: 0.5479
# Epoch 22/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.9036 - accuracy: 0.6529 - val_loss: 2.7399 - val_accuracy: 0.5482
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# Epoch 23/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.9045 - accuracy: 0.6533 - val_loss: 2.7392 - val_accuracy: 0.5476
# Epoch 24/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.9106 - accuracy: 0.6518 - val_loss: 2.7398 - val_accuracy: 0.5474
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.2799998785339995e-07.
# Epoch 25/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.9097 - accuracy: 0.6511 - val_loss: 2.7402 - val_accuracy: 0.5474
# Epoch 26/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.9019 - accuracy: 0.6515 - val_loss: 2.7398 - val_accuracy: 0.5468
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 2.5599996433811613e-08.
# Epoch 00026: early stopping
# ce_weights = 0.5, fcl_weights = 0.5
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 85us/step - loss: 3.2942 - accuracy: 0.3937 - val_loss: 3.2296 - val_accuracy: 0.3933
# Epoch 2/50
# 50000/50000 [==============================] - 4s 78us/step - loss: 2.7951 - accuracy: 0.4609 - val_loss: 2.9776 - val_accuracy: 0.4290
# Epoch 3/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 2.5988 - accuracy: 0.4946 - val_loss: 3.7345 - val_accuracy: 0.3543
# Epoch 4/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 2.4613 - accuracy: 0.5147 - val_loss: 3.2577 - val_accuracy: 0.4171
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 5/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 2.2483 - accuracy: 0.5513 - val_loss: 2.4871 - val_accuracy: 0.5158
# Epoch 6/50
# 50000/50000 [==============================] - 4s 77us/step - loss: 2.0844 - accuracy: 0.5796 - val_loss: 2.4176 - val_accuracy: 0.5285
# Epoch 7/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 2.0210 - accuracy: 0.5881 - val_loss: 2.4906 - val_accuracy: 0.5213
# Epoch 8/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.9625 - accuracy: 0.5992 - val_loss: 2.4670 - val_accuracy: 0.5216
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 9/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.8839 - accuracy: 0.6132 - val_loss: 2.3504 - val_accuracy: 0.5342
# Epoch 10/50
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.8304 - accuracy: 0.6215 - val_loss: 2.3475 - val_accuracy: 0.5396
# Epoch 11/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.8079 - accuracy: 0.6257 - val_loss: 2.3609 - val_accuracy: 0.5380
# Epoch 12/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.7904 - accuracy: 0.6281 - val_loss: 2.3565 - val_accuracy: 0.5389
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Epoch 13/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.7602 - accuracy: 0.6340 - val_loss: 2.3364 - val_accuracy: 0.5426
# Epoch 14/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.7510 - accuracy: 0.6353 - val_loss: 2.3411 - val_accuracy: 0.5439
# Epoch 15/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.7471 - accuracy: 0.6351 - val_loss: 2.3416 - val_accuracy: 0.5424
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# Epoch 16/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.7366 - accuracy: 0.6394 - val_loss: 2.3402 - val_accuracy: 0.5418
# Epoch 17/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.7371 - accuracy: 0.6391 - val_loss: 2.3404 - val_accuracy: 0.5420
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# Epoch 18/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.7324 - accuracy: 0.6403 - val_loss: 2.3407 - val_accuracy: 0.5428
# Epoch 19/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.7351 - accuracy: 0.6384 - val_loss: 2.3407 - val_accuracy: 0.5424
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# Epoch 20/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.7359 - accuracy: 0.6378 - val_loss: 2.3404 - val_accuracy: 0.5426
# Epoch 21/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.7345 - accuracy: 0.6382 - val_loss: 2.3406 - val_accuracy: 0.5425
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.2799998785339995e-07.
# Epoch 22/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.7344 - accuracy: 0.6386 - val_loss: 2.3399 - val_accuracy: 0.5423
# Epoch 23/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.7345 - accuracy: 0.6401 - val_loss: 2.3403 - val_accuracy: 0.5425
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 2.5599996433811613e-08.
# Epoch 00023: early stopping
# ce_weights = 0.7, fcl_weights = 0.30000000000000004
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 2.6367 - accuracy: 0.3983 - val_loss: 2.8396 - val_accuracy: 0.3545
# Epoch 2/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 2.2504 - accuracy: 0.4701 - val_loss: 2.5027 - val_accuracy: 0.4128
# Epoch 3/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 2.0966 - accuracy: 0.5007 - val_loss: 2.5161 - val_accuracy: 0.4235
# Epoch 4/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.9768 - accuracy: 0.5212 - val_loss: 2.5940 - val_accuracy: 0.4058
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 5/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.8218 - accuracy: 0.5593 - val_loss: 2.1239 - val_accuracy: 0.4991
# Epoch 6/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.6872 - accuracy: 0.5897 - val_loss: 2.0130 - val_accuracy: 0.5210
# Epoch 7/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.6348 - accuracy: 0.6004 - val_loss: 2.0908 - val_accuracy: 0.5146
# Epoch 8/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.5858 - accuracy: 0.6097 - val_loss: 1.9893 - val_accuracy: 0.5238
# Epoch 9/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.5430 - accuracy: 0.6203 - val_loss: 2.0299 - val_accuracy: 0.5221
# Epoch 10/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.5039 - accuracy: 0.6263 - val_loss: 2.0609 - val_accuracy: 0.5181
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 11/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.4255 - accuracy: 0.6451 - val_loss: 1.9363 - val_accuracy: 0.5427
# Epoch 12/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.3763 - accuracy: 0.6574 - val_loss: 1.9449 - val_accuracy: 0.5410
# Epoch 13/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.3603 - accuracy: 0.6615 - val_loss: 1.9563 - val_accuracy: 0.5406
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Epoch 14/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.3352 - accuracy: 0.6681 - val_loss: 1.9396 - val_accuracy: 0.5411
# Epoch 15/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.3285 - accuracy: 0.6696 - val_loss: 1.9400 - val_accuracy: 0.5425
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# Epoch 16/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.3209 - accuracy: 0.6709 - val_loss: 1.9402 - val_accuracy: 0.5416
# Epoch 17/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.3145 - accuracy: 0.6715 - val_loss: 1.9407 - val_accuracy: 0.5403
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# Epoch 18/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.3151 - accuracy: 0.6730 - val_loss: 1.9411 - val_accuracy: 0.5416
# Epoch 19/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.3141 - accuracy: 0.6714 - val_loss: 1.9411 - val_accuracy: 0.5412
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# Epoch 20/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.3177 - accuracy: 0.6714 - val_loss: 1.9410 - val_accuracy: 0.5407
# Epoch 21/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.3141 - accuracy: 0.6735 - val_loss: 1.9408 - val_accuracy: 0.5401
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.2799998785339995e-07.
# Epoch 00021: early stopping
# ce_weights = 1, fcl_weights = 0
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.6765 - accuracy: 0.4099 - val_loss: 1.7707 - val_accuracy: 0.3688
# Epoch 2/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.4457 - accuracy: 0.4860 - val_loss: 1.5998 - val_accuracy: 0.4315
# Epoch 3/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.3571 - accuracy: 0.5171 - val_loss: 1.6690 - val_accuracy: 0.4200
# Epoch 4/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.2895 - accuracy: 0.5412 - val_loss: 1.6257 - val_accuracy: 0.4304
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 5/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.1806 - accuracy: 0.5841 - val_loss: 1.3543 - val_accuracy: 0.5145
# Epoch 6/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.1152 - accuracy: 0.6059 - val_loss: 1.3425 - val_accuracy: 0.5225
# Epoch 7/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.0843 - accuracy: 0.6195 - val_loss: 1.3347 - val_accuracy: 0.5286
# Epoch 8/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.0576 - accuracy: 0.6281 - val_loss: 1.3530 - val_accuracy: 0.5239
# Epoch 9/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.0317 - accuracy: 0.6377 - val_loss: 1.3552 - val_accuracy: 0.5248
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 10/50
# 50000/50000 [==============================] - 4s 72us/step - loss: 0.9853 - accuracy: 0.6543 - val_loss: 1.3142 - val_accuracy: 0.5374
# Epoch 11/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.9644 - accuracy: 0.6634 - val_loss: 1.3099 - val_accuracy: 0.5398
# Epoch 12/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 0.9552 - accuracy: 0.6678 - val_loss: 1.3133 - val_accuracy: 0.5358
# Epoch 13/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 0.9458 - accuracy: 0.6684 - val_loss: 1.3160 - val_accuracy: 0.5376
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Epoch 14/50
# 50000/50000 [==============================] - 4s 72us/step - loss: 0.9322 - accuracy: 0.6759 - val_loss: 1.3106 - val_accuracy: 0.5403
# Epoch 15/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.9279 - accuracy: 0.6773 - val_loss: 1.3098 - val_accuracy: 0.5419
# Epoch 16/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.9243 - accuracy: 0.6796 - val_loss: 1.3106 - val_accuracy: 0.5401
# Epoch 17/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 0.9229 - accuracy: 0.6800 - val_loss: 1.3111 - val_accuracy: 0.5390
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# Epoch 18/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.9196 - accuracy: 0.6816 - val_loss: 1.3109 - val_accuracy: 0.5403
# Epoch 19/50
# 50000/50000 [==============================] - 4s 72us/step - loss: 0.9201 - accuracy: 0.6825 - val_loss: 1.3109 - val_accuracy: 0.5400
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# Epoch 20/50
# 50000/50000 [==============================] - 4s 72us/step - loss: 0.9195 - accuracy: 0.6823 - val_loss: 1.3106 - val_accuracy: 0.5405
# Epoch 21/50
# 50000/50000 [==============================] - 4s 75us/step - loss: 0.9185 - accuracy: 0.6810 - val_loss: 1.3107 - val_accuracy: 0.5403
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# Epoch 22/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.9181 - accuracy: 0.6841 - val_loss: 1.3108 - val_accuracy: 0.5399
# Epoch 23/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.9166 - accuracy: 0.6836 - val_loss: 1.3108 - val_accuracy: 0.5403
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.2799998785339995e-07.
# Epoch 24/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.9171 - accuracy: 0.6823 - val_loss: 1.3108 - val_accuracy: 0.5405
# Epoch 25/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.9190 - accuracy: 0.6806 - val_loss: 1.3108 - val_accuracy: 0.5404
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 2.5599996433811613e-08.
# Epoch 00025: early stopping

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
num_colors = len(results.keys())

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=num_colors-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(num_colors)]

plt.figure(figsize=(20, 15))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(20, 15))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
