# %% [markdown]
# ## Work
# 1. 請比較使用不同層數以及不同 Dropout rate 對訓練的效果
# 2. 將 optimizer 改成使用 Adam 並加上適當的 dropout rate 檢視結果

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import Dense, Dropout
def build_mlp(input_shape, output_units=10, num_neurons=[512, 128, 32], drop_ratio=0.3):
    """
    Build your own model
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
            x = Dropout(drop_ratio)(x)
        else:
            x = Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
            x = Dropout(drop_ratio)(x)
    
    out = Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
"""
Set your hyper-parameters
"""
epochs = 50
batch_size = 256
num_neurons = {'3': [512, 128, 32], '5': [512, 256, 128, 64, 32]}
drop_ratio = [0.0, 0.3, 0.6]

# %%
results = {}
"""
Set your training loop
"""
for nn in num_neurons:
    for dr in drop_ratio:
        keras.backend.clear_session() # 把舊的 Graph 清掉
        print(f'num_neurons = {nn}, drop_ratio = {dr}')
        model = build_mlp(input_shape=x_train.shape[1:], num_neurons=num_neurons[nn], drop_ratio=dr)
        model.summary()
        optimizer = keras.optimizers.SGD(lr=0.01, nesterov=True, momentum=0.9)
        model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

        model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), shuffle=True)

        # Collect results
        train_loss = model.history.history["loss"]
        valid_loss = model.history.history["val_loss"]
        train_acc = model.history.history["accuracy"]
        valid_acc = model.history.history["val_accuracy"]

        name_tag = f'num_neurons = {nn}, drop_ratio = {dr}'
        results[name_tag] = {'train-loss': train_loss, 'valid-loss': valid_loss, 
                             'train-acc': train_acc, 'valid-acc': valid_acc}
# Out:
# num_neurons = 3, drop_ratio = 0.0
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               65664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                4128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 1,643,498
# Trainable params: 1,643,498
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.9094 - accuracy: 0.3070 - val_loss: 1.7301 - val_accuracy: 0.3764
# Epoch 2/50
# 50000/50000 [==============================] - 2s 50us/step - loss: 1.6847 - accuracy: 0.3989 - val_loss: 1.7550 - val_accuracy: 0.3655
# Epoch 3/50
# 50000/50000 [==============================] - 2s 50us/step - loss: 1.5932 - accuracy: 0.4342 - val_loss: 1.5951 - val_accuracy: 0.4319
# Epoch 4/50
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.5232 - accuracy: 0.4584 - val_loss: 1.5846 - val_accuracy: 0.4280
# Epoch 5/50
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.4788 - accuracy: 0.4768 - val_loss: 1.4914 - val_accuracy: 0.4677
# Epoch 6/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.4336 - accuracy: 0.4921 - val_loss: 1.7896 - val_accuracy: 0.3797
# Epoch 7/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.4009 - accuracy: 0.5041 - val_loss: 1.4662 - val_accuracy: 0.4809
# Epoch 8/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.3614 - accuracy: 0.5142 - val_loss: 1.5774 - val_accuracy: 0.4452
# Epoch 9/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.3356 - accuracy: 0.5269 - val_loss: 1.5155 - val_accuracy: 0.4663
# Epoch 10/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.3073 - accuracy: 0.5367 - val_loss: 1.5028 - val_accuracy: 0.4687
# Epoch 11/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.2797 - accuracy: 0.5470 - val_loss: 1.4242 - val_accuracy: 0.4886
# Epoch 12/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.2597 - accuracy: 0.5514 - val_loss: 1.3750 - val_accuracy: 0.5160
# Epoch 13/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.2275 - accuracy: 0.5653 - val_loss: 1.3930 - val_accuracy: 0.5105
# Epoch 14/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.2177 - accuracy: 0.5662 - val_loss: 1.4373 - val_accuracy: 0.4932
# Epoch 15/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.1898 - accuracy: 0.5769 - val_loss: 1.5720 - val_accuracy: 0.4645
# Epoch 16/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.1677 - accuracy: 0.5876 - val_loss: 1.4279 - val_accuracy: 0.4975
# Epoch 17/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.1431 - accuracy: 0.5942 - val_loss: 1.4399 - val_accuracy: 0.4995
# Epoch 18/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.1257 - accuracy: 0.6030 - val_loss: 1.4690 - val_accuracy: 0.4889
# Epoch 19/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.1029 - accuracy: 0.6095 - val_loss: 1.4252 - val_accuracy: 0.4993
# Epoch 20/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.0866 - accuracy: 0.6117 - val_loss: 1.4382 - val_accuracy: 0.4972
# Epoch 21/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.0659 - accuracy: 0.6232 - val_loss: 1.3932 - val_accuracy: 0.5187
# Epoch 22/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.0424 - accuracy: 0.6313 - val_loss: 1.5419 - val_accuracy: 0.4867
# Epoch 23/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.0199 - accuracy: 0.6370 - val_loss: 1.4546 - val_accuracy: 0.5088
# Epoch 24/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.0123 - accuracy: 0.6412 - val_loss: 1.4416 - val_accuracy: 0.5128
# Epoch 25/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.9845 - accuracy: 0.6486 - val_loss: 1.4536 - val_accuracy: 0.5178
# Epoch 26/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.9642 - accuracy: 0.6574 - val_loss: 1.4227 - val_accuracy: 0.5274
# Epoch 27/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.9465 - accuracy: 0.6628 - val_loss: 1.4130 - val_accuracy: 0.5182
# Epoch 28/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.9385 - accuracy: 0.6659 - val_loss: 1.4478 - val_accuracy: 0.5156
# Epoch 29/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.9067 - accuracy: 0.6752 - val_loss: 1.4831 - val_accuracy: 0.5151
# Epoch 30/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.8995 - accuracy: 0.6809 - val_loss: 1.4864 - val_accuracy: 0.5004
# Epoch 31/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.8765 - accuracy: 0.6868 - val_loss: 1.5179 - val_accuracy: 0.5170
# Epoch 32/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.8552 - accuracy: 0.6954 - val_loss: 1.5843 - val_accuracy: 0.4969
# Epoch 33/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.8421 - accuracy: 0.6984 - val_loss: 1.5221 - val_accuracy: 0.5234
# Epoch 34/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.8245 - accuracy: 0.7052 - val_loss: 1.5580 - val_accuracy: 0.5076
# Epoch 35/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.8043 - accuracy: 0.7131 - val_loss: 1.5426 - val_accuracy: 0.5011
# Epoch 36/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.7919 - accuracy: 0.7173 - val_loss: 1.5166 - val_accuracy: 0.5242
# Epoch 37/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.7673 - accuracy: 0.7267 - val_loss: 1.5303 - val_accuracy: 0.5202
# Epoch 38/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.7566 - accuracy: 0.7295 - val_loss: 1.5305 - val_accuracy: 0.5253
# Epoch 39/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.7344 - accuracy: 0.7370 - val_loss: 1.6742 - val_accuracy: 0.5058
# Epoch 40/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.7313 - accuracy: 0.7379 - val_loss: 1.8335 - val_accuracy: 0.4951
# Epoch 41/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.7146 - accuracy: 0.7441 - val_loss: 1.6270 - val_accuracy: 0.5213
# Epoch 42/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.6881 - accuracy: 0.7522 - val_loss: 1.6270 - val_accuracy: 0.5283
# Epoch 43/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.6733 - accuracy: 0.7604 - val_loss: 1.7219 - val_accuracy: 0.5095
# Epoch 44/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.6708 - accuracy: 0.7609 - val_loss: 1.6429 - val_accuracy: 0.5222
# Epoch 45/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.6429 - accuracy: 0.7717 - val_loss: 1.7151 - val_accuracy: 0.5091
# Epoch 46/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.6424 - accuracy: 0.7695 - val_loss: 1.8052 - val_accuracy: 0.5050
# Epoch 47/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 0.6077 - accuracy: 0.7837 - val_loss: 1.8137 - val_accuracy: 0.5060
# Epoch 48/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 0.6001 - accuracy: 0.7854 - val_loss: 1.7820 - val_accuracy: 0.5039
# Epoch 49/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.5839 - accuracy: 0.7922 - val_loss: 1.8101 - val_accuracy: 0.5154
# Epoch 50/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.5710 - accuracy: 0.7943 - val_loss: 1.7743 - val_accuracy: 0.5206
# num_neurons = 3, drop_ratio = 0.3
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               65664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                4128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 1,643,498
# Trainable params: 1,643,498
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 2.1281 - accuracy: 0.2112 - val_loss: 1.9098 - val_accuracy: 0.3257
# Epoch 2/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9406 - accuracy: 0.2921 - val_loss: 1.7741 - val_accuracy: 0.3602
# Epoch 3/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.8712 - accuracy: 0.3197 - val_loss: 1.7268 - val_accuracy: 0.3820
# Epoch 4/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.8257 - accuracy: 0.3383 - val_loss: 1.6892 - val_accuracy: 0.3940
# Epoch 5/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.7890 - accuracy: 0.3542 - val_loss: 1.6635 - val_accuracy: 0.4115
# Epoch 6/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.7670 - accuracy: 0.3629 - val_loss: 1.6639 - val_accuracy: 0.4064
# Epoch 7/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.7400 - accuracy: 0.3743 - val_loss: 1.6284 - val_accuracy: 0.4268
# Epoch 8/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.7169 - accuracy: 0.3843 - val_loss: 1.5951 - val_accuracy: 0.4307
# Epoch 9/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.6969 - accuracy: 0.3936 - val_loss: 1.5760 - val_accuracy: 0.4423
# Epoch 10/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.6817 - accuracy: 0.3970 - val_loss: 1.5684 - val_accuracy: 0.4415
# Epoch 11/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.6601 - accuracy: 0.4068 - val_loss: 1.5207 - val_accuracy: 0.4579
# Epoch 12/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.6485 - accuracy: 0.4110 - val_loss: 1.5543 - val_accuracy: 0.4516
# Epoch 13/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.6343 - accuracy: 0.4177 - val_loss: 1.5127 - val_accuracy: 0.4647
# Epoch 14/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.6209 - accuracy: 0.4199 - val_loss: 1.5103 - val_accuracy: 0.4620
# Epoch 15/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.6090 - accuracy: 0.4271 - val_loss: 1.4971 - val_accuracy: 0.4708
# Epoch 16/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.5990 - accuracy: 0.4333 - val_loss: 1.4861 - val_accuracy: 0.4727
# Epoch 17/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.5919 - accuracy: 0.4305 - val_loss: 1.4906 - val_accuracy: 0.4686
# Epoch 18/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.5769 - accuracy: 0.4354 - val_loss: 1.5054 - val_accuracy: 0.4598
# Epoch 19/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.5719 - accuracy: 0.4396 - val_loss: 1.4783 - val_accuracy: 0.4731
# Epoch 20/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.5637 - accuracy: 0.4424 - val_loss: 1.4810 - val_accuracy: 0.4798
# Epoch 21/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.5526 - accuracy: 0.4467 - val_loss: 1.4761 - val_accuracy: 0.4704
# Epoch 22/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.5470 - accuracy: 0.4515 - val_loss: 1.4606 - val_accuracy: 0.4801
# Epoch 23/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.5387 - accuracy: 0.4516 - val_loss: 1.4285 - val_accuracy: 0.4865
# Epoch 24/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.5255 - accuracy: 0.4576 - val_loss: 1.4562 - val_accuracy: 0.4801
# Epoch 25/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.5129 - accuracy: 0.4636 - val_loss: 1.4157 - val_accuracy: 0.4914
# Epoch 26/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.5118 - accuracy: 0.4614 - val_loss: 1.4511 - val_accuracy: 0.4838
# Epoch 27/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.5163 - accuracy: 0.4627 - val_loss: 1.4223 - val_accuracy: 0.4954
# Epoch 28/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4961 - accuracy: 0.4665 - val_loss: 1.4057 - val_accuracy: 0.4953
# Epoch 29/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.4832 - accuracy: 0.4700 - val_loss: 1.4244 - val_accuracy: 0.4950
# Epoch 30/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.4877 - accuracy: 0.4696 - val_loss: 1.4074 - val_accuracy: 0.4992
# Epoch 31/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.4795 - accuracy: 0.4748 - val_loss: 1.4027 - val_accuracy: 0.4968
# Epoch 32/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4618 - accuracy: 0.4809 - val_loss: 1.4108 - val_accuracy: 0.4988
# Epoch 33/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.4666 - accuracy: 0.4804 - val_loss: 1.3963 - val_accuracy: 0.5006
# Epoch 34/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4664 - accuracy: 0.4778 - val_loss: 1.4111 - val_accuracy: 0.5003
# Epoch 35/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4603 - accuracy: 0.4873 - val_loss: 1.4064 - val_accuracy: 0.4954
# Epoch 36/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4477 - accuracy: 0.4858 - val_loss: 1.3965 - val_accuracy: 0.4992
# Epoch 37/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.4427 - accuracy: 0.4913 - val_loss: 1.3877 - val_accuracy: 0.5045
# Epoch 38/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.4435 - accuracy: 0.4899 - val_loss: 1.3935 - val_accuracy: 0.4997
# Epoch 39/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4367 - accuracy: 0.4913 - val_loss: 1.3794 - val_accuracy: 0.5081
# Epoch 40/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.4296 - accuracy: 0.4973 - val_loss: 1.3852 - val_accuracy: 0.5072
# Epoch 41/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4213 - accuracy: 0.4963 - val_loss: 1.3785 - val_accuracy: 0.5063
# Epoch 42/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.4195 - accuracy: 0.4972 - val_loss: 1.3684 - val_accuracy: 0.5081
# Epoch 43/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4171 - accuracy: 0.4990 - val_loss: 1.3800 - val_accuracy: 0.5063
# Epoch 44/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.4028 - accuracy: 0.5010 - val_loss: 1.3700 - val_accuracy: 0.5098
# Epoch 45/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.3993 - accuracy: 0.5031 - val_loss: 1.3616 - val_accuracy: 0.5103
# Epoch 46/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.3947 - accuracy: 0.5081 - val_loss: 1.3582 - val_accuracy: 0.5134
# Epoch 47/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.3837 - accuracy: 0.5093 - val_loss: 1.3684 - val_accuracy: 0.5138
# Epoch 48/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.3830 - accuracy: 0.5118 - val_loss: 1.3588 - val_accuracy: 0.5158
# Epoch 49/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.3855 - accuracy: 0.5093 - val_loss: 1.3512 - val_accuracy: 0.5223
# Epoch 50/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.3746 - accuracy: 0.5148 - val_loss: 1.3304 - val_accuracy: 0.5281
# num_neurons = 3, drop_ratio = 0.6
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               65664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                4128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 1,643,498
# Trainable params: 1,643,498
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.3148 - accuracy: 0.1195 - val_loss: 2.2524 - val_accuracy: 0.1832
# Epoch 2/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.2267 - accuracy: 0.1494 - val_loss: 2.1292 - val_accuracy: 0.2099
# Epoch 3/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.1586 - accuracy: 0.1708 - val_loss: 2.0847 - val_accuracy: 0.2371
# Epoch 4/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 2.1269 - accuracy: 0.1804 - val_loss: 2.0361 - val_accuracy: 0.2482
# Epoch 5/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 2.1046 - accuracy: 0.1924 - val_loss: 2.0254 - val_accuracy: 0.2371
# Epoch 6/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.0966 - accuracy: 0.1974 - val_loss: 2.0114 - val_accuracy: 0.2380
# Epoch 7/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 2.0764 - accuracy: 0.2025 - val_loss: 2.0056 - val_accuracy: 0.2284
# Epoch 8/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 2.0687 - accuracy: 0.2053 - val_loss: 1.9896 - val_accuracy: 0.2590
# Epoch 9/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.0561 - accuracy: 0.2129 - val_loss: 1.9853 - val_accuracy: 0.2633
# Epoch 10/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.0438 - accuracy: 0.2153 - val_loss: 1.9864 - val_accuracy: 0.2483
# Epoch 11/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 2.0440 - accuracy: 0.2149 - val_loss: 1.9862 - val_accuracy: 0.2602
# Epoch 12/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.0386 - accuracy: 0.2204 - val_loss: 1.9952 - val_accuracy: 0.2483
# Epoch 13/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 2.0245 - accuracy: 0.2225 - val_loss: 1.9907 - val_accuracy: 0.2542
# Epoch 14/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 2.0215 - accuracy: 0.2262 - val_loss: 1.9844 - val_accuracy: 0.2626
# Epoch 15/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 2.0164 - accuracy: 0.2274 - val_loss: 1.9447 - val_accuracy: 0.2761
# Epoch 16/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.0174 - accuracy: 0.2292 - val_loss: 1.9667 - val_accuracy: 0.2627
# Epoch 17/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.0045 - accuracy: 0.2303 - val_loss: 1.9258 - val_accuracy: 0.2755
# Epoch 18/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 2.0020 - accuracy: 0.2300 - val_loss: 1.9447 - val_accuracy: 0.2676
# Epoch 19/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.9999 - accuracy: 0.2346 - val_loss: 1.9502 - val_accuracy: 0.2752
# Epoch 20/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.9902 - accuracy: 0.2374 - val_loss: 1.9339 - val_accuracy: 0.2711
# Epoch 21/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9905 - accuracy: 0.2391 - val_loss: 1.9271 - val_accuracy: 0.2647
# Epoch 22/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.9868 - accuracy: 0.2383 - val_loss: 1.9569 - val_accuracy: 0.2712
# Epoch 23/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9774 - accuracy: 0.2389 - val_loss: 1.9171 - val_accuracy: 0.2726
# Epoch 24/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.9768 - accuracy: 0.2413 - val_loss: 1.9239 - val_accuracy: 0.2691
# Epoch 25/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9667 - accuracy: 0.2433 - val_loss: 1.9156 - val_accuracy: 0.2825
# Epoch 26/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9695 - accuracy: 0.2414 - val_loss: 1.9259 - val_accuracy: 0.2704
# Epoch 27/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9634 - accuracy: 0.2447 - val_loss: 1.8961 - val_accuracy: 0.2851
# Epoch 28/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9579 - accuracy: 0.2473 - val_loss: 1.9119 - val_accuracy: 0.2818
# Epoch 29/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.9580 - accuracy: 0.2494 - val_loss: 1.9048 - val_accuracy: 0.2870
# Epoch 30/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.9538 - accuracy: 0.2505 - val_loss: 1.9036 - val_accuracy: 0.2952
# Epoch 31/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.9490 - accuracy: 0.2529 - val_loss: 1.8951 - val_accuracy: 0.3050
# Epoch 32/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9484 - accuracy: 0.2529 - val_loss: 1.8794 - val_accuracy: 0.3039
# Epoch 33/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.9470 - accuracy: 0.2553 - val_loss: 1.9121 - val_accuracy: 0.2786
# Epoch 34/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9427 - accuracy: 0.2568 - val_loss: 1.8981 - val_accuracy: 0.3084
# Epoch 35/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.9410 - accuracy: 0.2579 - val_loss: 1.8759 - val_accuracy: 0.3093
# Epoch 36/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.9318 - accuracy: 0.2607 - val_loss: 1.8585 - val_accuracy: 0.3104
# Epoch 37/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9358 - accuracy: 0.2596 - val_loss: 1.8942 - val_accuracy: 0.3001
# Epoch 38/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.9297 - accuracy: 0.2656 - val_loss: 1.8934 - val_accuracy: 0.2992
# Epoch 39/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.9336 - accuracy: 0.2621 - val_loss: 1.8834 - val_accuracy: 0.3008
# Epoch 40/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.9283 - accuracy: 0.2639 - val_loss: 1.8787 - val_accuracy: 0.3122
# Epoch 41/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.9245 - accuracy: 0.2637 - val_loss: 1.8775 - val_accuracy: 0.3257
# Epoch 42/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.9203 - accuracy: 0.2673 - val_loss: 1.8763 - val_accuracy: 0.3068
# Epoch 43/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9186 - accuracy: 0.2684 - val_loss: 1.8581 - val_accuracy: 0.3173
# Epoch 44/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.9125 - accuracy: 0.2718 - val_loss: 1.8642 - val_accuracy: 0.3159
# Epoch 45/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.9136 - accuracy: 0.2693 - val_loss: 1.8707 - val_accuracy: 0.3151
# Epoch 46/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.9106 - accuracy: 0.2737 - val_loss: 1.8525 - val_accuracy: 0.3229
# Epoch 47/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.9090 - accuracy: 0.2703 - val_loss: 1.8553 - val_accuracy: 0.3206
# Epoch 48/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9040 - accuracy: 0.2730 - val_loss: 1.8479 - val_accuracy: 0.3407
# Epoch 49/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.9039 - accuracy: 0.2767 - val_loss: 1.8568 - val_accuracy: 0.3276
# Epoch 50/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.9023 - accuracy: 0.2761 - val_loss: 1.8391 - val_accuracy: 0.3302
# num_neurons = 5, drop_ratio = 0.0
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# hidden_layer5 (Dense)        (None, 32)                2080
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 1,748,266
# Trainable params: 1,748,266
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.9377 - accuracy: 0.2963 - val_loss: 1.8618 - val_accuracy: 0.3458
# Epoch 2/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.6799 - accuracy: 0.4013 - val_loss: 1.8280 - val_accuracy: 0.3475
# Epoch 3/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.5826 - accuracy: 0.4372 - val_loss: 1.6110 - val_accuracy: 0.4294
# Epoch 4/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.5140 - accuracy: 0.4613 - val_loss: 1.6750 - val_accuracy: 0.4241
# Epoch 5/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 1.4633 - accuracy: 0.4794 - val_loss: 1.4810 - val_accuracy: 0.4636
# Epoch 6/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.4139 - accuracy: 0.4966 - val_loss: 1.4468 - val_accuracy: 0.4807
# Epoch 7/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.3848 - accuracy: 0.5063 - val_loss: 1.4174 - val_accuracy: 0.4908
# Epoch 8/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.3444 - accuracy: 0.5216 - val_loss: 1.4773 - val_accuracy: 0.4742
# Epoch 9/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.3208 - accuracy: 0.5306 - val_loss: 1.4966 - val_accuracy: 0.4590
# Epoch 10/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.2883 - accuracy: 0.5417 - val_loss: 1.3956 - val_accuracy: 0.4997
# Epoch 11/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.2584 - accuracy: 0.5523 - val_loss: 1.4104 - val_accuracy: 0.5018
# Epoch 12/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.2321 - accuracy: 0.5616 - val_loss: 1.4391 - val_accuracy: 0.4876
# Epoch 13/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.2080 - accuracy: 0.5704 - val_loss: 1.5933 - val_accuracy: 0.4441
# Epoch 14/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.1818 - accuracy: 0.5799 - val_loss: 1.4932 - val_accuracy: 0.4863
# Epoch 15/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.1505 - accuracy: 0.5885 - val_loss: 1.3772 - val_accuracy: 0.5121
# Epoch 16/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.1269 - accuracy: 0.6001 - val_loss: 1.3761 - val_accuracy: 0.5188
# Epoch 17/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.1036 - accuracy: 0.6060 - val_loss: 1.3563 - val_accuracy: 0.5288
# Epoch 18/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.0804 - accuracy: 0.6146 - val_loss: 1.3805 - val_accuracy: 0.5307
# Epoch 19/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.0611 - accuracy: 0.6200 - val_loss: 1.4777 - val_accuracy: 0.4946
# Epoch 20/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.0429 - accuracy: 0.6264 - val_loss: 1.5244 - val_accuracy: 0.4881
# Epoch 21/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.0090 - accuracy: 0.6410 - val_loss: 1.4626 - val_accuracy: 0.4908
# Epoch 22/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.9857 - accuracy: 0.6480 - val_loss: 1.5255 - val_accuracy: 0.5012
# Epoch 23/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.9633 - accuracy: 0.6546 - val_loss: 1.4850 - val_accuracy: 0.5133
# Epoch 24/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.9464 - accuracy: 0.6600 - val_loss: 1.4270 - val_accuracy: 0.5239
# Epoch 25/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.9186 - accuracy: 0.6739 - val_loss: 1.5700 - val_accuracy: 0.4984
# Epoch 26/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.9042 - accuracy: 0.6779 - val_loss: 1.4604 - val_accuracy: 0.5232
# Epoch 27/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.8753 - accuracy: 0.6881 - val_loss: 1.4645 - val_accuracy: 0.5280
# Epoch 28/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.8562 - accuracy: 0.6945 - val_loss: 1.4809 - val_accuracy: 0.5291
# Epoch 29/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.8316 - accuracy: 0.7001 - val_loss: 1.5006 - val_accuracy: 0.5261
# Epoch 30/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.8147 - accuracy: 0.7073 - val_loss: 1.4908 - val_accuracy: 0.5406
# Epoch 31/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.7925 - accuracy: 0.7161 - val_loss: 1.5970 - val_accuracy: 0.5138
# Epoch 32/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.7692 - accuracy: 0.7240 - val_loss: 1.6414 - val_accuracy: 0.5193
# Epoch 33/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.7511 - accuracy: 0.7327 - val_loss: 1.7529 - val_accuracy: 0.5024
# Epoch 34/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.7396 - accuracy: 0.7332 - val_loss: 1.8385 - val_accuracy: 0.4822
# Epoch 35/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.7113 - accuracy: 0.7436 - val_loss: 1.6155 - val_accuracy: 0.5233
# Epoch 36/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.6984 - accuracy: 0.7494 - val_loss: 1.8909 - val_accuracy: 0.4930
# Epoch 37/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.6743 - accuracy: 0.7590 - val_loss: 1.8727 - val_accuracy: 0.4820
# Epoch 38/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.6519 - accuracy: 0.7669 - val_loss: 1.8636 - val_accuracy: 0.4938
# Epoch 39/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.6499 - accuracy: 0.7655 - val_loss: 1.6965 - val_accuracy: 0.5186
# Epoch 40/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.6191 - accuracy: 0.7798 - val_loss: 1.6999 - val_accuracy: 0.5271
# Epoch 41/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.6035 - accuracy: 0.7829 - val_loss: 1.7147 - val_accuracy: 0.5327
# Epoch 42/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.5686 - accuracy: 0.7968 - val_loss: 1.8825 - val_accuracy: 0.5059
# Epoch 43/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.5640 - accuracy: 0.7970 - val_loss: 1.8301 - val_accuracy: 0.5268
# Epoch 44/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.5536 - accuracy: 0.8014 - val_loss: 2.0550 - val_accuracy: 0.4781
# Epoch 45/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.5435 - accuracy: 0.8056 - val_loss: 1.9014 - val_accuracy: 0.5132
# Epoch 46/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.5063 - accuracy: 0.8171 - val_loss: 1.8621 - val_accuracy: 0.5283
# Epoch 47/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.5066 - accuracy: 0.8193 - val_loss: 2.1019 - val_accuracy: 0.5234
# Epoch 48/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.5006 - accuracy: 0.8210 - val_loss: 1.9808 - val_accuracy: 0.5151
# Epoch 49/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.5003 - accuracy: 0.8207 - val_loss: 2.1414 - val_accuracy: 0.5163
# Epoch 50/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.4637 - accuracy: 0.8339 - val_loss: 2.0959 - val_accuracy: 0.5176
# num_neurons = 5, drop_ratio = 0.3
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# hidden_layer5 (Dense)        (None, 32)                2080
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 1,748,266
# Trainable params: 1,748,266
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 2.2471 - accuracy: 0.1440 - val_loss: 2.0906 - val_accuracy: 0.1896
# Epoch 2/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 2.0917 - accuracy: 0.1930 - val_loss: 1.9650 - val_accuracy: 0.2772
# Epoch 3/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 2.0041 - accuracy: 0.2384 - val_loss: 1.8959 - val_accuracy: 0.3016
# Epoch 4/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.9617 - accuracy: 0.2618 - val_loss: 1.8703 - val_accuracy: 0.2993
# Epoch 5/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.9289 - accuracy: 0.2763 - val_loss: 1.8370 - val_accuracy: 0.3175
# Epoch 6/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.9071 - accuracy: 0.2851 - val_loss: 1.8272 - val_accuracy: 0.3407
# Epoch 7/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.8828 - accuracy: 0.2964 - val_loss: 1.7680 - val_accuracy: 0.3644
# Epoch 8/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.8611 - accuracy: 0.3060 - val_loss: 1.7419 - val_accuracy: 0.3661
# Epoch 9/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.8436 - accuracy: 0.3176 - val_loss: 1.7200 - val_accuracy: 0.3818
# Epoch 10/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.8213 - accuracy: 0.3260 - val_loss: 1.7071 - val_accuracy: 0.3948
# Epoch 11/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.8045 - accuracy: 0.3383 - val_loss: 1.6902 - val_accuracy: 0.3966
# Epoch 12/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.7920 - accuracy: 0.3422 - val_loss: 1.6901 - val_accuracy: 0.3998
# Epoch 13/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.7753 - accuracy: 0.3508 - val_loss: 1.6615 - val_accuracy: 0.4029
# Epoch 14/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.7686 - accuracy: 0.3558 - val_loss: 1.6679 - val_accuracy: 0.4025
# Epoch 15/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.7581 - accuracy: 0.3635 - val_loss: 1.6268 - val_accuracy: 0.4187
# Epoch 16/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.7385 - accuracy: 0.3690 - val_loss: 1.6129 - val_accuracy: 0.4263
# Epoch 17/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.7283 - accuracy: 0.3731 - val_loss: 1.6142 - val_accuracy: 0.4268
# Epoch 18/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.7190 - accuracy: 0.3775 - val_loss: 1.6174 - val_accuracy: 0.4230
# Epoch 19/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.7106 - accuracy: 0.3822 - val_loss: 1.5821 - val_accuracy: 0.4360
# Epoch 20/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.6972 - accuracy: 0.3894 - val_loss: 1.5768 - val_accuracy: 0.4315
# Epoch 21/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.6929 - accuracy: 0.3913 - val_loss: 1.5843 - val_accuracy: 0.4390
# Epoch 22/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.6845 - accuracy: 0.3953 - val_loss: 1.5613 - val_accuracy: 0.4406
# Epoch 23/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.6653 - accuracy: 0.3965 - val_loss: 1.5883 - val_accuracy: 0.4313
# Epoch 24/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.6719 - accuracy: 0.4018 - val_loss: 1.5618 - val_accuracy: 0.4375
# Epoch 25/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.6593 - accuracy: 0.4025 - val_loss: 1.5464 - val_accuracy: 0.4443
# Epoch 26/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.6522 - accuracy: 0.4076 - val_loss: 1.5714 - val_accuracy: 0.4420
# Epoch 27/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.6448 - accuracy: 0.4129 - val_loss: 1.5493 - val_accuracy: 0.4534
# Epoch 28/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.6248 - accuracy: 0.4182 - val_loss: 1.5320 - val_accuracy: 0.4541
# Epoch 29/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.6323 - accuracy: 0.4148 - val_loss: 1.5481 - val_accuracy: 0.4448
# Epoch 30/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.6258 - accuracy: 0.4177 - val_loss: 1.5541 - val_accuracy: 0.4474
# Epoch 31/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.6142 - accuracy: 0.4191 - val_loss: 1.5351 - val_accuracy: 0.4505
# Epoch 32/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.6118 - accuracy: 0.4256 - val_loss: 1.5277 - val_accuracy: 0.4447
# Epoch 33/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.6063 - accuracy: 0.4250 - val_loss: 1.4878 - val_accuracy: 0.4672
# Epoch 34/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.5975 - accuracy: 0.4289 - val_loss: 1.5022 - val_accuracy: 0.4646
# Epoch 35/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.5836 - accuracy: 0.4310 - val_loss: 1.4860 - val_accuracy: 0.4714
# Epoch 36/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.5821 - accuracy: 0.4325 - val_loss: 1.4854 - val_accuracy: 0.4709
# Epoch 37/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.5770 - accuracy: 0.4371 - val_loss: 1.5142 - val_accuracy: 0.4625
# Epoch 38/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.5731 - accuracy: 0.4404 - val_loss: 1.4949 - val_accuracy: 0.4665
# Epoch 39/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.5730 - accuracy: 0.4410 - val_loss: 1.4696 - val_accuracy: 0.4738
# Epoch 40/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.5644 - accuracy: 0.4429 - val_loss: 1.4927 - val_accuracy: 0.4713
# Epoch 41/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.5598 - accuracy: 0.4433 - val_loss: 1.4695 - val_accuracy: 0.4745
# Epoch 42/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.5442 - accuracy: 0.4485 - val_loss: 1.4659 - val_accuracy: 0.4746
# Epoch 43/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.5503 - accuracy: 0.4513 - val_loss: 1.5243 - val_accuracy: 0.4511
# Epoch 44/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.5423 - accuracy: 0.4488 - val_loss: 1.4575 - val_accuracy: 0.4723
# Epoch 45/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.5330 - accuracy: 0.4543 - val_loss: 1.4562 - val_accuracy: 0.4775
# Epoch 46/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.5291 - accuracy: 0.4560 - val_loss: 1.4525 - val_accuracy: 0.4828
# Epoch 47/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.5193 - accuracy: 0.4587 - val_loss: 1.4442 - val_accuracy: 0.4810
# Epoch 48/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.5144 - accuracy: 0.4607 - val_loss: 1.4502 - val_accuracy: 0.4772
# Epoch 49/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 1.5125 - accuracy: 0.4594 - val_loss: 1.4348 - val_accuracy: 0.4868
# Epoch 50/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.5137 - accuracy: 0.4647 - val_loss: 1.4380 - val_accuracy: 0.4835
# num_neurons = 5, drop_ratio = 0.6
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# hidden_layer5 (Dense)        (None, 32)                2080
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 1,748,266
# Trainable params: 1,748,266
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 2.3282 - accuracy: 0.1058 - val_loss: 2.3020 - val_accuracy: 0.1000
# Epoch 2/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.2933 - accuracy: 0.1237 - val_loss: 2.2968 - val_accuracy: 0.1178
# Epoch 3/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.2569 - accuracy: 0.1462 - val_loss: 2.2437 - val_accuracy: 0.1663
# Epoch 4/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 2.2153 - accuracy: 0.1517 - val_loss: 2.2333 - val_accuracy: 0.1485
# Epoch 5/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 2.1944 - accuracy: 0.1543 - val_loss: 2.2521 - val_accuracy: 0.1156
# Epoch 6/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.1790 - accuracy: 0.1541 - val_loss: 2.2051 - val_accuracy: 0.1401
# Epoch 7/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.1661 - accuracy: 0.1588 - val_loss: 2.2571 - val_accuracy: 0.1163
# Epoch 8/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.1603 - accuracy: 0.1591 - val_loss: 2.2588 - val_accuracy: 0.1136
# Epoch 9/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 2.1501 - accuracy: 0.1625 - val_loss: 2.2821 - val_accuracy: 0.1086
# Epoch 10/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.1416 - accuracy: 0.1675 - val_loss: 2.2303 - val_accuracy: 0.1221
# Epoch 11/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.1334 - accuracy: 0.1650 - val_loss: 2.2724 - val_accuracy: 0.1077
# Epoch 12/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.1257 - accuracy: 0.1697 - val_loss: 2.2606 - val_accuracy: 0.1135
# Epoch 13/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 2.1259 - accuracy: 0.1690 - val_loss: 2.2491 - val_accuracy: 0.1128
# Epoch 14/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 2.1261 - accuracy: 0.1690 - val_loss: 2.2541 - val_accuracy: 0.1116
# Epoch 15/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 2.1220 - accuracy: 0.1699 - val_loss: 2.2580 - val_accuracy: 0.1126
# Epoch 16/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 2.1151 - accuracy: 0.1698 - val_loss: 2.2992 - val_accuracy: 0.1038
# Epoch 17/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 2.1154 - accuracy: 0.1708 - val_loss: 2.2489 - val_accuracy: 0.1176
# Epoch 18/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.1071 - accuracy: 0.1744 - val_loss: 2.2598 - val_accuracy: 0.1106
# Epoch 19/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 2.1026 - accuracy: 0.1725 - val_loss: 2.2684 - val_accuracy: 0.1079
# Epoch 20/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 2.1023 - accuracy: 0.1726 - val_loss: 2.2845 - val_accuracy: 0.1092
# Epoch 21/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.1039 - accuracy: 0.1719 - val_loss: 2.3078 - val_accuracy: 0.1049
# Epoch 22/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0984 - accuracy: 0.1726 - val_loss: 2.2689 - val_accuracy: 0.1097
# Epoch 23/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.0962 - accuracy: 0.1714 - val_loss: 2.2474 - val_accuracy: 0.1146
# Epoch 24/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 2.0966 - accuracy: 0.1739 - val_loss: 2.2492 - val_accuracy: 0.1122
# Epoch 25/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0900 - accuracy: 0.1734 - val_loss: 2.2648 - val_accuracy: 0.1075
# Epoch 26/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.0852 - accuracy: 0.1747 - val_loss: 2.2985 - val_accuracy: 0.1066
# Epoch 27/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0874 - accuracy: 0.1746 - val_loss: 2.2585 - val_accuracy: 0.1094
# Epoch 28/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.0853 - accuracy: 0.1766 - val_loss: 2.2613 - val_accuracy: 0.1087
# Epoch 29/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 2.0771 - accuracy: 0.1740 - val_loss: 2.2812 - val_accuracy: 0.1080
# Epoch 30/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 2.0813 - accuracy: 0.1778 - val_loss: 2.2819 - val_accuracy: 0.1062
# Epoch 31/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.0774 - accuracy: 0.1770 - val_loss: 2.2855 - val_accuracy: 0.1051
# Epoch 32/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0779 - accuracy: 0.1775 - val_loss: 2.2339 - val_accuracy: 0.1229
# Epoch 33/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.0734 - accuracy: 0.1767 - val_loss: 2.2289 - val_accuracy: 0.1196
# Epoch 34/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 2.0774 - accuracy: 0.1759 - val_loss: 2.2546 - val_accuracy: 0.1108
# Epoch 35/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0751 - accuracy: 0.1792 - val_loss: 2.2693 - val_accuracy: 0.1077
# Epoch 36/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0774 - accuracy: 0.1775 - val_loss: 2.2718 - val_accuracy: 0.1075
# Epoch 37/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0676 - accuracy: 0.1813 - val_loss: 2.2750 - val_accuracy: 0.1081
# Epoch 38/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.0679 - accuracy: 0.1784 - val_loss: 2.2259 - val_accuracy: 0.1162
# Epoch 39/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 2.0672 - accuracy: 0.1819 - val_loss: 2.2667 - val_accuracy: 0.1088
# Epoch 40/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0604 - accuracy: 0.1833 - val_loss: 2.2834 - val_accuracy: 0.1058
# Epoch 41/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.0640 - accuracy: 0.1810 - val_loss: 2.2750 - val_accuracy: 0.1091
# Epoch 42/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0575 - accuracy: 0.1832 - val_loss: 2.2501 - val_accuracy: 0.1137
# Epoch 43/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.0590 - accuracy: 0.1835 - val_loss: 2.2473 - val_accuracy: 0.1109
# Epoch 44/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0623 - accuracy: 0.1832 - val_loss: 2.2614 - val_accuracy: 0.1104
# Epoch 45/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 2.0580 - accuracy: 0.1835 - val_loss: 2.2633 - val_accuracy: 0.1113
# Epoch 46/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0591 - accuracy: 0.1844 - val_loss: 2.2464 - val_accuracy: 0.1166
# Epoch 47/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0529 - accuracy: 0.1859 - val_loss: 2.2713 - val_accuracy: 0.1109
# Epoch 48/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.0497 - accuracy: 0.1861 - val_loss: 2.2714 - val_accuracy: 0.1143
# Epoch 49/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.0499 - accuracy: 0.1875 - val_loss: 2.2869 - val_accuracy: 0.1056
# Epoch 50/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 2.0552 - accuracy: 0.1833 - val_loss: 2.2733 - val_accuracy: 0.1081

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""
plot the results
"""
plt.style.use('ggplot')
color_bar = ['w', 'r', 'y', 'g', 'b', 'k']

plt.figure(figsize=(20, 15))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(20, 15))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
