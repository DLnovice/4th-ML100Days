# %% [markdown]
# ## Work
# 1. 試改變 monitor "Validation Accuracy" 並比較結果
# 2. 調整 earlystop 的等待次數至 10, 25 並比較結果

# %%
import os
import keras
import matplotlib.pyplot as plt
# %matplotlib inline

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import Input, Dense, BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):    
    """
    Build your own model
    """
    input_layer = Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
"""
Set your hyper-parameters
"""
epochs = 50
batch_size = 256
monitor = ['val_loss', 'val_accuracy']
patience = [5, 10, 25]

# %%
results = {}
# 載入 Callbacks
"""
Earlystop setting
"""
from keras.callbacks import EarlyStopping

for moni in monitor:
    for pati in patience:
        earlystop = EarlyStopping(monitor=moni, patience=pati, verbose=1)
        """
        Your Training loop and Plot the results
        """
        keras.backend.clear_session() # 把舊的 Graph 清掉
        print(f'monitor = {moni}, patience = {pati}')
        model = build_mlp(input_shape=x_train.shape[1:])
        model.summary()
        optimizer = keras.optimizers.SGD(lr=0.01, nesterov=True, momentum=0.95)
        model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

        model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), shuffle=True, 
                  callbacks=[earlystop])

        # Collect results
        train_loss = model.history.history["loss"]
        valid_loss = model.history.history["val_loss"]
        train_acc = model.history.history["accuracy"]
        valid_acc = model.history.history["val_accuracy"]
        
        name_tag = f'monitor = {moni}, patience = {pati}'
        results[name_tag] = {'train-loss': train_loss, 'valid-loss': valid_loss, 
                             'train-acc': train_acc, 'valid-acc': valid_acc}
# Out:
# monitor = val_loss, patience = 5
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.6813 - accuracy: 0.4097 - val_loss: 1.6651 - val_accuracy: 0.4035
# Epoch 2/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4440 - accuracy: 0.4895 - val_loss: 1.6359 - val_accuracy: 0.4060
# Epoch 3/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.3483 - accuracy: 0.5197 - val_loss: 1.5897 - val_accuracy: 0.4435
# Epoch 4/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.2800 - accuracy: 0.5461 - val_loss: 1.6517 - val_accuracy: 0.4177
# Epoch 5/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.2252 - accuracy: 0.5652 - val_loss: 1.5254 - val_accuracy: 0.4677
# Epoch 6/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.1684 - accuracy: 0.5848 - val_loss: 1.7040 - val_accuracy: 0.4189
# Epoch 7/50
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.1309 - accuracy: 0.5988 - val_loss: 1.6298 - val_accuracy: 0.4307
# Epoch 8/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.0908 - accuracy: 0.6107 - val_loss: 1.5855 - val_accuracy: 0.4550
# Epoch 9/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.0540 - accuracy: 0.6243 - val_loss: 1.5826 - val_accuracy: 0.4586
# Epoch 10/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 1.0282 - accuracy: 0.6350 - val_loss: 1.6611 - val_accuracy: 0.4368
# Epoch 00010: early stopping
# monitor = val_loss, patience = 10
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.6783 - accuracy: 0.4089 - val_loss: 1.6534 - val_accuracy: 0.4105
# Epoch 2/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.4408 - accuracy: 0.4873 - val_loss: 1.5663 - val_accuracy: 0.4481
# Epoch 3/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.3483 - accuracy: 0.5205 - val_loss: 1.9001 - val_accuracy: 0.3405
# Epoch 4/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.2866 - accuracy: 0.5455 - val_loss: 1.7299 - val_accuracy: 0.4082
# Epoch 5/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.2256 - accuracy: 0.5639 - val_loss: 1.7495 - val_accuracy: 0.4060
# Epoch 6/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 1.1729 - accuracy: 0.5831 - val_loss: 1.6118 - val_accuracy: 0.4414
# Epoch 7/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 1.1312 - accuracy: 0.5989 - val_loss: 1.6582 - val_accuracy: 0.4404
# Epoch 8/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 1.0856 - accuracy: 0.6152 - val_loss: 1.6448 - val_accuracy: 0.4418
# Epoch 9/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0473 - accuracy: 0.6288 - val_loss: 1.7651 - val_accuracy: 0.4203
# Epoch 10/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.0178 - accuracy: 0.6407 - val_loss: 1.6304 - val_accuracy: 0.4549
# Epoch 11/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9855 - accuracy: 0.6494 - val_loss: 1.6302 - val_accuracy: 0.4586
# Epoch 12/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.9451 - accuracy: 0.6655 - val_loss: 1.6565 - val_accuracy: 0.4583
# Epoch 00012: early stopping
# monitor = val_loss, patience = 25
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.6893 - accuracy: 0.4038 - val_loss: 1.7248 - val_accuracy: 0.3981
# Epoch 2/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.4544 - accuracy: 0.4810 - val_loss: 1.6814 - val_accuracy: 0.4063
# Epoch 3/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.3580 - accuracy: 0.5165 - val_loss: 1.5408 - val_accuracy: 0.4533
# Epoch 4/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.2818 - accuracy: 0.5424 - val_loss: 1.8542 - val_accuracy: 0.3657
# Epoch 5/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.2249 - accuracy: 0.5629 - val_loss: 1.7645 - val_accuracy: 0.3940
# Epoch 6/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.1750 - accuracy: 0.5835 - val_loss: 1.5691 - val_accuracy: 0.4490
# Epoch 7/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.1252 - accuracy: 0.5988 - val_loss: 1.6056 - val_accuracy: 0.4503
# Epoch 8/50
# 50000/50000 [==============================] - 4s 72us/step - loss: 1.0878 - accuracy: 0.6146 - val_loss: 1.6575 - val_accuracy: 0.4380
# Epoch 9/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0485 - accuracy: 0.6275 - val_loss: 1.5215 - val_accuracy: 0.4671
# Epoch 10/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.0165 - accuracy: 0.6372 - val_loss: 1.7224 - val_accuracy: 0.4330
# Epoch 11/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.9831 - accuracy: 0.6500 - val_loss: 1.7328 - val_accuracy: 0.4454
# Epoch 12/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.9466 - accuracy: 0.6616 - val_loss: 1.6340 - val_accuracy: 0.4585
# Epoch 13/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9164 - accuracy: 0.6743 - val_loss: 1.8622 - val_accuracy: 0.4147
# Epoch 14/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.8961 - accuracy: 0.6804 - val_loss: 1.9399 - val_accuracy: 0.4164
# Epoch 15/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.8542 - accuracy: 0.6952 - val_loss: 1.6343 - val_accuracy: 0.4723
# Epoch 16/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.8231 - accuracy: 0.7056 - val_loss: 1.8042 - val_accuracy: 0.4517
# Epoch 17/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.7962 - accuracy: 0.7168 - val_loss: 1.7224 - val_accuracy: 0.4647
# Epoch 18/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7743 - accuracy: 0.7239 - val_loss: 1.8683 - val_accuracy: 0.4534
# Epoch 19/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.7490 - accuracy: 0.7335 - val_loss: 1.7008 - val_accuracy: 0.4807
# Epoch 20/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.7147 - accuracy: 0.7461 - val_loss: 1.8777 - val_accuracy: 0.4629
# Epoch 21/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.6891 - accuracy: 0.7520 - val_loss: 1.9047 - val_accuracy: 0.4406
# Epoch 22/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.6636 - accuracy: 0.7633 - val_loss: 2.0496 - val_accuracy: 0.4351
# Epoch 23/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.6540 - accuracy: 0.7681 - val_loss: 2.1113 - val_accuracy: 0.4714
# Epoch 24/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.6242 - accuracy: 0.7763 - val_loss: 1.9101 - val_accuracy: 0.4663
# Epoch 25/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.5989 - accuracy: 0.7869 - val_loss: 2.3660 - val_accuracy: 0.4181
# Epoch 26/50
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.5727 - accuracy: 0.7955 - val_loss: 2.1423 - val_accuracy: 0.4559
# Epoch 27/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.5508 - accuracy: 0.8018 - val_loss: 2.0475 - val_accuracy: 0.4443
# Epoch 28/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.5361 - accuracy: 0.8086 - val_loss: 2.3319 - val_accuracy: 0.4197
# Epoch 29/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.5154 - accuracy: 0.8143 - val_loss: 2.2403 - val_accuracy: 0.4679
# Epoch 30/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.5005 - accuracy: 0.8216 - val_loss: 2.2857 - val_accuracy: 0.4427
# Epoch 31/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.4644 - accuracy: 0.8345 - val_loss: 2.4140 - val_accuracy: 0.4507
# Epoch 32/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4490 - accuracy: 0.8394 - val_loss: 2.3622 - val_accuracy: 0.4585
# Epoch 33/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4376 - accuracy: 0.8442 - val_loss: 2.2399 - val_accuracy: 0.4662
# Epoch 34/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.4246 - accuracy: 0.8468 - val_loss: 2.3078 - val_accuracy: 0.4657
# Epoch 00034: early stopping
# monitor = val_accuracy, patience = 5
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.6941 - accuracy: 0.4029 - val_loss: 1.7471 - val_accuracy: 0.3810
# Epoch 2/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.4493 - accuracy: 0.4858 - val_loss: 1.7230 - val_accuracy: 0.3975
# Epoch 3/50
# 50000/50000 [==============================] - 4s 72us/step - loss: 1.3582 - accuracy: 0.5169 - val_loss: 1.8030 - val_accuracy: 0.3696
# Epoch 4/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.2903 - accuracy: 0.5416 - val_loss: 1.5877 - val_accuracy: 0.4408
# Epoch 5/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.2319 - accuracy: 0.5622 - val_loss: 1.7079 - val_accuracy: 0.4073
# Epoch 6/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.1804 - accuracy: 0.5805 - val_loss: 1.5346 - val_accuracy: 0.4574
# Epoch 7/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.1403 - accuracy: 0.5953 - val_loss: 1.5247 - val_accuracy: 0.4683
# Epoch 8/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0924 - accuracy: 0.6116 - val_loss: 1.5878 - val_accuracy: 0.4468
# Epoch 9/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.0498 - accuracy: 0.6255 - val_loss: 1.8332 - val_accuracy: 0.4021
# Epoch 10/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0230 - accuracy: 0.6364 - val_loss: 1.7731 - val_accuracy: 0.4249
# Epoch 11/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.9945 - accuracy: 0.6451 - val_loss: 1.7511 - val_accuracy: 0.4448
# Epoch 12/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.9591 - accuracy: 0.6573 - val_loss: 1.6650 - val_accuracy: 0.4685
# Epoch 13/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9209 - accuracy: 0.6709 - val_loss: 1.8717 - val_accuracy: 0.4085
# Epoch 14/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.8990 - accuracy: 0.6823 - val_loss: 1.8572 - val_accuracy: 0.4333
# Epoch 15/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.8688 - accuracy: 0.6895 - val_loss: 1.7783 - val_accuracy: 0.4457
# Epoch 16/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.8338 - accuracy: 0.7042 - val_loss: 1.8576 - val_accuracy: 0.4383
# Epoch 17/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.8070 - accuracy: 0.7130 - val_loss: 1.8293 - val_accuracy: 0.4344
# Epoch 00017: early stopping
# monitor = val_accuracy, patience = 10
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.6865 - accuracy: 0.4067 - val_loss: 1.6449 - val_accuracy: 0.4233
# Epoch 2/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.4558 - accuracy: 0.4852 - val_loss: 1.5829 - val_accuracy: 0.4271
# Epoch 3/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.3546 - accuracy: 0.5178 - val_loss: 1.6856 - val_accuracy: 0.4061
# Epoch 4/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.2835 - accuracy: 0.5450 - val_loss: 1.4902 - val_accuracy: 0.4766
# Epoch 5/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.2228 - accuracy: 0.5635 - val_loss: 1.6015 - val_accuracy: 0.4396
# Epoch 6/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.1750 - accuracy: 0.5839 - val_loss: 1.7699 - val_accuracy: 0.3994
# Epoch 7/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.1396 - accuracy: 0.5934 - val_loss: 1.7237 - val_accuracy: 0.4191
# Epoch 8/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.0948 - accuracy: 0.6110 - val_loss: 1.5440 - val_accuracy: 0.4505
# Epoch 9/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.0476 - accuracy: 0.6290 - val_loss: 1.7397 - val_accuracy: 0.4221
# Epoch 10/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0185 - accuracy: 0.6378 - val_loss: 1.7553 - val_accuracy: 0.4056
# Epoch 11/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.9880 - accuracy: 0.6489 - val_loss: 1.6044 - val_accuracy: 0.4648
# Epoch 12/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.9526 - accuracy: 0.6601 - val_loss: 1.7327 - val_accuracy: 0.4385
# Epoch 13/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.9268 - accuracy: 0.6686 - val_loss: 1.6771 - val_accuracy: 0.4592
# Epoch 14/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.9016 - accuracy: 0.6798 - val_loss: 1.9237 - val_accuracy: 0.4118
# Epoch 00014: early stopping
# monitor = val_accuracy, patience = 25
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.6849 - accuracy: 0.4053 - val_loss: 1.6390 - val_accuracy: 0.4150
# Epoch 2/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.4496 - accuracy: 0.4855 - val_loss: 1.6569 - val_accuracy: 0.4098
# Epoch 3/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.3597 - accuracy: 0.5134 - val_loss: 1.5370 - val_accuracy: 0.4499
# Epoch 4/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.2931 - accuracy: 0.5387 - val_loss: 1.5757 - val_accuracy: 0.4310
# Epoch 5/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.2373 - accuracy: 0.5593 - val_loss: 1.5711 - val_accuracy: 0.4391
# Epoch 6/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.1902 - accuracy: 0.5765 - val_loss: 1.7395 - val_accuracy: 0.4189
# Epoch 7/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.1425 - accuracy: 0.5930 - val_loss: 1.6014 - val_accuracy: 0.4392
# Epoch 8/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.0995 - accuracy: 0.6089 - val_loss: 1.7008 - val_accuracy: 0.4331
# Epoch 9/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.0630 - accuracy: 0.6182 - val_loss: 1.6194 - val_accuracy: 0.4486
# Epoch 10/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0168 - accuracy: 0.6367 - val_loss: 1.6966 - val_accuracy: 0.4385
# Epoch 11/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.9876 - accuracy: 0.6486 - val_loss: 1.6697 - val_accuracy: 0.4478
# Epoch 12/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.9523 - accuracy: 0.6607 - val_loss: 1.5993 - val_accuracy: 0.4644
# Epoch 13/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.9203 - accuracy: 0.6720 - val_loss: 1.6582 - val_accuracy: 0.4536
# Epoch 14/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.9017 - accuracy: 0.6778 - val_loss: 1.9630 - val_accuracy: 0.4259
# Epoch 15/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.8680 - accuracy: 0.6937 - val_loss: 1.6837 - val_accuracy: 0.4621
# Epoch 16/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.8296 - accuracy: 0.7048 - val_loss: 1.8203 - val_accuracy: 0.4476
# Epoch 17/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.8076 - accuracy: 0.7118 - val_loss: 1.7575 - val_accuracy: 0.4450
# Epoch 18/50
# 50000/50000 [==============================] - 4s 70us/step - loss: 0.7769 - accuracy: 0.7219 - val_loss: 1.8016 - val_accuracy: 0.4414
# Epoch 19/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.7578 - accuracy: 0.7283 - val_loss: 2.0007 - val_accuracy: 0.4212
# Epoch 20/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.7372 - accuracy: 0.7373 - val_loss: 1.8692 - val_accuracy: 0.4602
# Epoch 21/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.7027 - accuracy: 0.7488 - val_loss: 2.0134 - val_accuracy: 0.4373
# Epoch 22/50
# 50000/50000 [==============================] - 4s 70us/step - loss: 0.6694 - accuracy: 0.7597 - val_loss: 1.8633 - val_accuracy: 0.4690
# Epoch 23/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 0.6538 - accuracy: 0.7657 - val_loss: 1.9913 - val_accuracy: 0.4508
# Epoch 24/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.6280 - accuracy: 0.7770 - val_loss: 2.1558 - val_accuracy: 0.4292
# Epoch 25/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.6118 - accuracy: 0.7799 - val_loss: 2.0343 - val_accuracy: 0.4504
# Epoch 26/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.5956 - accuracy: 0.7869 - val_loss: 2.0583 - val_accuracy: 0.4625
# Epoch 27/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.5606 - accuracy: 0.7973 - val_loss: 2.0763 - val_accuracy: 0.4676
# Epoch 28/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.5395 - accuracy: 0.8066 - val_loss: 2.1057 - val_accuracy: 0.4568
# Epoch 29/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.5182 - accuracy: 0.8132 - val_loss: 2.4275 - val_accuracy: 0.4547
# Epoch 30/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4895 - accuracy: 0.8239 - val_loss: 2.5465 - val_accuracy: 0.4396
# Epoch 31/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4755 - accuracy: 0.8293 - val_loss: 2.2572 - val_accuracy: 0.4512
# Epoch 32/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.4699 - accuracy: 0.8307 - val_loss: 2.2871 - val_accuracy: 0.4441
# Epoch 33/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4394 - accuracy: 0.8424 - val_loss: 2.3016 - val_accuracy: 0.4464
# Epoch 34/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4231 - accuracy: 0.8477 - val_loss: 2.4286 - val_accuracy: 0.4545
# Epoch 35/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.4106 - accuracy: 0.8535 - val_loss: 2.4763 - val_accuracy: 0.4526
# Epoch 36/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.3931 - accuracy: 0.8575 - val_loss: 2.5617 - val_accuracy: 0.4535
# Epoch 37/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.3675 - accuracy: 0.8669 - val_loss: 2.5057 - val_accuracy: 0.4705
# Epoch 38/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.3537 - accuracy: 0.8731 - val_loss: 2.6507 - val_accuracy: 0.4563
# Epoch 39/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.3544 - accuracy: 0.8720 - val_loss: 2.6109 - val_accuracy: 0.4655
# Epoch 40/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.3321 - accuracy: 0.8789 - val_loss: 2.4530 - val_accuracy: 0.4774
# Epoch 41/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.3262 - accuracy: 0.8819 - val_loss: 2.6222 - val_accuracy: 0.4646
# Epoch 42/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.3009 - accuracy: 0.8937 - val_loss: 2.8737 - val_accuracy: 0.4644
# Epoch 43/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.2883 - accuracy: 0.8973 - val_loss: 2.7307 - val_accuracy: 0.4627
# Epoch 44/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.2885 - accuracy: 0.8975 - val_loss: 2.8377 - val_accuracy: 0.4653
# Epoch 45/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.2733 - accuracy: 0.9026 - val_loss: 2.7668 - val_accuracy: 0.4738
# Epoch 46/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.2586 - accuracy: 0.9086 - val_loss: 2.8508 - val_accuracy: 0.4751
# Epoch 47/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.2511 - accuracy: 0.9089 - val_loss: 2.7329 - val_accuracy: 0.4716
# Epoch 48/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.2570 - accuracy: 0.9078 - val_loss: 2.8087 - val_accuracy: 0.4768
# Epoch 49/50
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.2495 - accuracy: 0.9116 - val_loss: 2.9950 - val_accuracy: 0.4554
# Epoch 50/50
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.2402 - accuracy: 0.9154 - val_loss: 2.9871 - val_accuracy: 0.4659

# %%
plt.style.use('ggplot')
color_bar = ['r', 'm', 'y', 'g', 'b', 'k']

plt.figure(figsize=(20, 15))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(20, 15))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
