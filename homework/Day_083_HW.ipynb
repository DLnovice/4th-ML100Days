# %% [markdown]
# ## Work
# 1. 試比較有 BN 在 Batch_size = 2, 16, 32, 128, 256 下的差異
# 2. 請嘗試將 BN 放在 Activation 之前，並比較訓練結果
# 3. 請於 BN 放在 Input Layer 後，並比較結果

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import Input, Dense, BatchNormalization, Activation
def build_mlp(input_shape, output_units=10, num_neurons=[512, 128, 32]):    
    """
    Build your own model
    """
    input_layer = Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
"""
Set your hyper-parameters
"""
epochs = 50
batch_size = [32, 128, 256]

# %%
results = {}
"""
Write your training loop and record results
"""
for bs in batch_size:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print(f'batch_size = {bs}')
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=0.01, nesterov=True, momentum=0.9)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, epochs=epochs, batch_size=bs, validation_data=(x_test, y_test), shuffle=True)

    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]

    name_tag = f'batch_size = {bs}'
    results[name_tag] = {'train-loss': train_loss, 'valid-loss': valid_loss, 
                         'train-acc': train_acc, 'valid-acc': valid_acc}
# Out:
# batch_size = 32
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               65664
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                4128
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 1,646,186
# Trainable params: 1,644,842
# Non-trainable params: 1,344
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 16s 318us/step - loss: 1.7328 - accuracy: 0.3811 - val_loss: 1.6669 - val_accuracy: 0.4037
# Epoch 2/50
# 50000/50000 [==============================] - 15s 302us/step - loss: 1.5915 - accuracy: 0.4307 - val_loss: 1.5782 - val_accuracy: 0.4392
# Epoch 3/50
# 50000/50000 [==============================] - 15s 301us/step - loss: 1.5528 - accuracy: 0.4452 - val_loss: 1.6462 - val_accuracy: 0.4141
# Epoch 4/50
# 50000/50000 [==============================] - 15s 305us/step - loss: 1.5129 - accuracy: 0.4584 - val_loss: 1.5054 - val_accuracy: 0.4584
# Epoch 5/50
# 50000/50000 [==============================] - 16s 322us/step - loss: 1.4750 - accuracy: 0.4708 - val_loss: 1.6642 - val_accuracy: 0.4115
# Epoch 6/50
# 50000/50000 [==============================] - 14s 287us/step - loss: 1.4544 - accuracy: 0.4836 - val_loss: 1.5292 - val_accuracy: 0.4488
# Epoch 7/50
# 50000/50000 [==============================] - 15s 297us/step - loss: 1.4241 - accuracy: 0.4921 - val_loss: 1.4687 - val_accuracy: 0.4720
# Epoch 8/50
# 50000/50000 [==============================] - 14s 286us/step - loss: 1.3971 - accuracy: 0.5004 - val_loss: 1.4706 - val_accuracy: 0.4758
# Epoch 9/50
# 50000/50000 [==============================] - 14s 284us/step - loss: 1.3782 - accuracy: 0.5097 - val_loss: 1.4756 - val_accuracy: 0.4723
# Epoch 10/50
# 50000/50000 [==============================] - 14s 285us/step - loss: 1.3593 - accuracy: 0.5178 - val_loss: 1.4649 - val_accuracy: 0.4825
# Epoch 11/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.3427 - accuracy: 0.5209 - val_loss: 1.5200 - val_accuracy: 0.4658
# Epoch 12/50
# 50000/50000 [==============================] - 15s 296us/step - loss: 1.3314 - accuracy: 0.5275 - val_loss: 1.4696 - val_accuracy: 0.4819
# Epoch 13/50
# 50000/50000 [==============================] - 14s 289us/step - loss: 1.3187 - accuracy: 0.5306 - val_loss: 1.4128 - val_accuracy: 0.5021
# Epoch 14/50
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.3001 - accuracy: 0.5395 - val_loss: 1.4144 - val_accuracy: 0.4951
# Epoch 15/50
# 50000/50000 [==============================] - 14s 289us/step - loss: 1.2838 - accuracy: 0.5430 - val_loss: 1.4195 - val_accuracy: 0.4966
# Epoch 16/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.2782 - accuracy: 0.5457 - val_loss: 4.4934 - val_accuracy: 0.1584
# Epoch 17/50
# 50000/50000 [==============================] - 15s 306us/step - loss: 1.2693 - accuracy: 0.5494 - val_loss: 1.4392 - val_accuracy: 0.4944
# Epoch 18/50
# 50000/50000 [==============================] - 17s 344us/step - loss: 1.2588 - accuracy: 0.5531 - val_loss: 1.4582 - val_accuracy: 0.4872
# Epoch 19/50
# 50000/50000 [==============================] - 17s 337us/step - loss: 1.2560 - accuracy: 0.5531 - val_loss: 1.3815 - val_accuracy: 0.5105
# Epoch 20/50
# 50000/50000 [==============================] - 15s 290us/step - loss: 1.2503 - accuracy: 0.5579 - val_loss: 1.4575 - val_accuracy: 0.4895
# Epoch 21/50
# 50000/50000 [==============================] - 14s 272us/step - loss: 1.2397 - accuracy: 0.5610 - val_loss: 1.4171 - val_accuracy: 0.4976
# Epoch 22/50
# 50000/50000 [==============================] - 14s 279us/step - loss: 1.2307 - accuracy: 0.5628 - val_loss: 1.3744 - val_accuracy: 0.5170
# Epoch 23/50
# 50000/50000 [==============================] - 16s 317us/step - loss: 1.2239 - accuracy: 0.5643 - val_loss: 1.3702 - val_accuracy: 0.5178
# Epoch 24/50
# 50000/50000 [==============================] - 15s 305us/step - loss: 1.2181 - accuracy: 0.5686 - val_loss: 1.3953 - val_accuracy: 0.5045
# Epoch 25/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.2139 - accuracy: 0.5669 - val_loss: 1.4144 - val_accuracy: 0.5048
# Epoch 26/50
# 50000/50000 [==============================] - 16s 315us/step - loss: 1.2101 - accuracy: 0.5699 - val_loss: 1.4506 - val_accuracy: 0.4940
# Epoch 27/50
# 50000/50000 [==============================] - 15s 292us/step - loss: 1.1995 - accuracy: 0.5736 - val_loss: 1.4014 - val_accuracy: 0.5094
# Epoch 28/50
# 50000/50000 [==============================] - 14s 288us/step - loss: 1.2006 - accuracy: 0.5738 - val_loss: 1.4676 - val_accuracy: 0.4838
# Epoch 29/50
# 50000/50000 [==============================] - 15s 292us/step - loss: 1.1946 - accuracy: 0.5747 - val_loss: 1.4110 - val_accuracy: 0.5030
# Epoch 30/50
# 50000/50000 [==============================] - 14s 288us/step - loss: 1.1859 - accuracy: 0.5776 - val_loss: 1.4579 - val_accuracy: 0.4971
# Epoch 31/50
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.1796 - accuracy: 0.5834 - val_loss: 1.3882 - val_accuracy: 0.5147
# Epoch 32/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 1.1718 - accuracy: 0.5843 - val_loss: 1.3759 - val_accuracy: 0.5100
# Epoch 33/50
# 50000/50000 [==============================] - 15s 296us/step - loss: 1.1698 - accuracy: 0.5839 - val_loss: 1.4432 - val_accuracy: 0.4992
# Epoch 34/50
# 50000/50000 [==============================] - 14s 279us/step - loss: 1.1708 - accuracy: 0.5837 - val_loss: 1.4298 - val_accuracy: 0.4977
# Epoch 35/50
# 50000/50000 [==============================] - 16s 322us/step - loss: 1.1615 - accuracy: 0.5859 - val_loss: 1.3966 - val_accuracy: 0.5078
# Epoch 36/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.1538 - accuracy: 0.5883 - val_loss: 1.4014 - val_accuracy: 0.5172
# Epoch 37/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 1.1511 - accuracy: 0.5924 - val_loss: 1.4041 - val_accuracy: 0.5054
# Epoch 38/50
# 50000/50000 [==============================] - 18s 360us/step - loss: 1.1442 - accuracy: 0.5935 - val_loss: 1.4138 - val_accuracy: 0.5086
# Epoch 39/50
# 50000/50000 [==============================] - 17s 334us/step - loss: 1.1442 - accuracy: 0.5917 - val_loss: 1.4240 - val_accuracy: 0.5060
# Epoch 40/50
# 50000/50000 [==============================] - 17s 336us/step - loss: 1.1374 - accuracy: 0.5922 - val_loss: 1.4162 - val_accuracy: 0.5167
# Epoch 41/50
# 50000/50000 [==============================] - 17s 345us/step - loss: 1.1333 - accuracy: 0.5960 - val_loss: 1.5027 - val_accuracy: 0.4909
# Epoch 42/50
# 50000/50000 [==============================] - 17s 332us/step - loss: 1.1287 - accuracy: 0.5975 - val_loss: 1.5410 - val_accuracy: 0.4754
# Epoch 43/50
# 50000/50000 [==============================] - 18s 354us/step - loss: 1.1265 - accuracy: 0.6006 - val_loss: 1.3996 - val_accuracy: 0.5086
# Epoch 44/50
# 50000/50000 [==============================] - 19s 387us/step - loss: 1.1239 - accuracy: 0.6015 - val_loss: 1.4862 - val_accuracy: 0.4951
# Epoch 45/50
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.1198 - accuracy: 0.6013 - val_loss: 1.4168 - val_accuracy: 0.5082
# Epoch 46/50
# 50000/50000 [==============================] - 17s 342us/step - loss: 1.1122 - accuracy: 0.6029 - val_loss: 1.4245 - val_accuracy: 0.5070
# Epoch 47/50
# 50000/50000 [==============================] - 17s 337us/step - loss: 1.1061 - accuracy: 0.6063 - val_loss: 1.4304 - val_accuracy: 0.4998
# Epoch 48/50
# 50000/50000 [==============================] - 16s 311us/step - loss: 1.1087 - accuracy: 0.6049 - val_loss: 1.4257 - val_accuracy: 0.5067
# Epoch 49/50
# 50000/50000 [==============================] - 16s 310us/step - loss: 1.1206 - accuracy: 0.6006 - val_loss: 1.4284 - val_accuracy: 0.5100
# Epoch 50/50
# 50000/50000 [==============================] - 19s 388us/step - loss: 1.1149 - accuracy: 0.6019 - val_loss: 1.4660 - val_accuracy: 0.4915
# batch_size = 128
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               65664
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                4128
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 1,646,186
# Trainable params: 1,644,842
# Non-trainable params: 1,344
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 8s 153us/step - loss: 1.7140 - accuracy: 0.3939 - val_loss: 1.6460 - val_accuracy: 0.4133
# Epoch 2/50
# 50000/50000 [==============================] - 7s 142us/step - loss: 1.4977 - accuracy: 0.4648 - val_loss: 1.6094 - val_accuracy: 0.4205
# Epoch 3/50
# 50000/50000 [==============================] - 7s 141us/step - loss: 1.4137 - accuracy: 0.4959 - val_loss: 1.6684 - val_accuracy: 0.4023
# Epoch 4/50
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.3647 - accuracy: 0.5123 - val_loss: 1.6613 - val_accuracy: 0.4110
# Epoch 5/50
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.3232 - accuracy: 0.5258 - val_loss: 1.7055 - val_accuracy: 0.4054
# Epoch 6/50
# 50000/50000 [==============================] - 7s 144us/step - loss: 1.2910 - accuracy: 0.5380 - val_loss: 1.6317 - val_accuracy: 0.4177
# Epoch 7/50
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.2648 - accuracy: 0.5491 - val_loss: 1.5053 - val_accuracy: 0.4685
# Epoch 8/50
# 50000/50000 [==============================] - 8s 166us/step - loss: 1.2376 - accuracy: 0.5585 - val_loss: 1.4939 - val_accuracy: 0.4792
# Epoch 9/50
# 50000/50000 [==============================] - 8s 155us/step - loss: 1.2124 - accuracy: 0.5665 - val_loss: 1.5454 - val_accuracy: 0.4588
# Epoch 10/50
# 50000/50000 [==============================] - 8s 166us/step - loss: 1.1961 - accuracy: 0.5733 - val_loss: 1.6266 - val_accuracy: 0.4323
# Epoch 11/50
# 50000/50000 [==============================] - 9s 177us/step - loss: 1.1786 - accuracy: 0.5772 - val_loss: 1.7530 - val_accuracy: 0.4081
# Epoch 12/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 1.1546 - accuracy: 0.5858 - val_loss: 1.6712 - val_accuracy: 0.4223
# Epoch 13/50
# 50000/50000 [==============================] - 8s 157us/step - loss: 1.1393 - accuracy: 0.5940 - val_loss: 1.6424 - val_accuracy: 0.4300
# Epoch 14/50
# 50000/50000 [==============================] - 7s 141us/step - loss: 1.1226 - accuracy: 0.5989 - val_loss: 1.5713 - val_accuracy: 0.4515
# Epoch 15/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 1.0958 - accuracy: 0.6072 - val_loss: 1.5395 - val_accuracy: 0.4680
# Epoch 16/50
# 50000/50000 [==============================] - 7s 141us/step - loss: 1.0853 - accuracy: 0.6129 - val_loss: 1.5450 - val_accuracy: 0.4703
# Epoch 17/50
# 50000/50000 [==============================] - 7s 147us/step - loss: 1.0749 - accuracy: 0.6147 - val_loss: 1.5179 - val_accuracy: 0.4686
# Epoch 18/50
# 50000/50000 [==============================] - 7s 150us/step - loss: 1.0624 - accuracy: 0.6193 - val_loss: 1.6372 - val_accuracy: 0.4508
# Epoch 19/50
# 50000/50000 [==============================] - 7s 148us/step - loss: 1.0488 - accuracy: 0.6239 - val_loss: 1.6147 - val_accuracy: 0.4701
# Epoch 20/50
# 50000/50000 [==============================] - 7s 146us/step - loss: 1.0357 - accuracy: 0.6315 - val_loss: 1.6536 - val_accuracy: 0.4666
# Epoch 21/50
# 50000/50000 [==============================] - 8s 153us/step - loss: 1.0321 - accuracy: 0.6307 - val_loss: 1.6437 - val_accuracy: 0.4491
# Epoch 22/50
# 50000/50000 [==============================] - 7s 145us/step - loss: 1.0129 - accuracy: 0.6382 - val_loss: 1.7313 - val_accuracy: 0.4427
# Epoch 23/50
# 50000/50000 [==============================] - 8s 152us/step - loss: 0.9947 - accuracy: 0.6436 - val_loss: 1.6922 - val_accuracy: 0.4483
# Epoch 24/50
# 50000/50000 [==============================] - 7s 146us/step - loss: 0.9823 - accuracy: 0.6465 - val_loss: 1.5981 - val_accuracy: 0.4658
# Epoch 25/50
# 50000/50000 [==============================] - 8s 156us/step - loss: 0.9759 - accuracy: 0.6498 - val_loss: 1.5104 - val_accuracy: 0.5077
# Epoch 26/50
# 50000/50000 [==============================] - 8s 152us/step - loss: 0.9669 - accuracy: 0.6529 - val_loss: 1.7281 - val_accuracy: 0.4470
# Epoch 27/50
# 50000/50000 [==============================] - 8s 160us/step - loss: 0.9529 - accuracy: 0.6592 - val_loss: 1.5679 - val_accuracy: 0.4901
# Epoch 28/50
# 50000/50000 [==============================] - 7s 145us/step - loss: 0.9488 - accuracy: 0.6598 - val_loss: 1.6125 - val_accuracy: 0.4862
# Epoch 29/50
# 50000/50000 [==============================] - 8s 150us/step - loss: 0.9458 - accuracy: 0.6604 - val_loss: 1.7100 - val_accuracy: 0.4522
# Epoch 30/50
# 50000/50000 [==============================] - 7s 146us/step - loss: 0.9206 - accuracy: 0.6676 - val_loss: 1.6739 - val_accuracy: 0.4569
# Epoch 31/50
# 50000/50000 [==============================] - 8s 156us/step - loss: 0.9109 - accuracy: 0.6722 - val_loss: 1.6623 - val_accuracy: 0.4644
# Epoch 32/50
# 50000/50000 [==============================] - 8s 155us/step - loss: 0.8960 - accuracy: 0.6779 - val_loss: 1.7896 - val_accuracy: 0.4538
# Epoch 33/50
# 50000/50000 [==============================] - 8s 160us/step - loss: 0.8888 - accuracy: 0.6785 - val_loss: 1.7031 - val_accuracy: 0.4559
# Epoch 34/50
# 50000/50000 [==============================] - 8s 154us/step - loss: 0.8787 - accuracy: 0.6841 - val_loss: 1.8344 - val_accuracy: 0.4535
# Epoch 35/50
# 50000/50000 [==============================] - 8s 153us/step - loss: 0.8709 - accuracy: 0.6888 - val_loss: 1.6473 - val_accuracy: 0.4820
# Epoch 36/50
# 50000/50000 [==============================] - 7s 148us/step - loss: 0.8617 - accuracy: 0.6904 - val_loss: 1.7403 - val_accuracy: 0.4557
# Epoch 37/50
# 50000/50000 [==============================] - 7s 148us/step - loss: 0.8468 - accuracy: 0.6967 - val_loss: 1.6525 - val_accuracy: 0.4825
# Epoch 38/50
# 50000/50000 [==============================] - 8s 152us/step - loss: 0.8406 - accuracy: 0.6970 - val_loss: 1.6637 - val_accuracy: 0.4872
# Epoch 39/50
# 50000/50000 [==============================] - 7s 150us/step - loss: 0.8242 - accuracy: 0.7043 - val_loss: 1.7910 - val_accuracy: 0.4619
# Epoch 40/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 0.8148 - accuracy: 0.7054 - val_loss: 1.7325 - val_accuracy: 0.4666
# Epoch 41/50
# 50000/50000 [==============================] - 8s 155us/step - loss: 0.8107 - accuracy: 0.7075 - val_loss: 1.7925 - val_accuracy: 0.4659
# Epoch 42/50
# 50000/50000 [==============================] - 8s 155us/step - loss: 0.7974 - accuracy: 0.7145 - val_loss: 1.7990 - val_accuracy: 0.4668
# Epoch 43/50
# 50000/50000 [==============================] - 8s 152us/step - loss: 0.7870 - accuracy: 0.7172 - val_loss: 1.7683 - val_accuracy: 0.4695
# Epoch 44/50
# 50000/50000 [==============================] - 9s 186us/step - loss: 0.7876 - accuracy: 0.7171 - val_loss: 1.7765 - val_accuracy: 0.4727
# Epoch 45/50
# 50000/50000 [==============================] - 8s 153us/step - loss: 0.7847 - accuracy: 0.7191 - val_loss: 1.9102 - val_accuracy: 0.4642
# Epoch 46/50
# 50000/50000 [==============================] - 8s 158us/step - loss: 0.7646 - accuracy: 0.7248 - val_loss: 1.8464 - val_accuracy: 0.4593
# Epoch 47/50
# 50000/50000 [==============================] - 8s 161us/step - loss: 0.7624 - accuracy: 0.7257 - val_loss: 2.0914 - val_accuracy: 0.4345
# Epoch 48/50
# 50000/50000 [==============================] - 8s 164us/step - loss: 0.7539 - accuracy: 0.7281 - val_loss: 1.8652 - val_accuracy: 0.4597
# Epoch 49/50
# 50000/50000 [==============================] - 8s 153us/step - loss: 0.7437 - accuracy: 0.7310 - val_loss: 1.8704 - val_accuracy: 0.4706
# Epoch 50/50
# 50000/50000 [==============================] - 8s 164us/step - loss: 0.7420 - accuracy: 0.7328 - val_loss: 1.9537 - val_accuracy: 0.4358
# batch_size = 256
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               65664
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                4128
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 1,646,186
# Trainable params: 1,644,842
# Non-trainable params: 1,344
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 1.7228 - accuracy: 0.3960 - val_loss: 1.6893 - val_accuracy: 0.4048
# Epoch 2/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.4985 - accuracy: 0.4680 - val_loss: 1.6201 - val_accuracy: 0.4205
# Epoch 3/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 1.4096 - accuracy: 0.5006 - val_loss: 1.6602 - val_accuracy: 0.4078
# Epoch 4/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.3534 - accuracy: 0.5190 - val_loss: 1.7016 - val_accuracy: 0.4063
# Epoch 5/50
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.2993 - accuracy: 0.5381 - val_loss: 1.5334 - val_accuracy: 0.4534
# Epoch 6/50
# 50000/50000 [==============================] - 6s 118us/step - loss: 1.2601 - accuracy: 0.5535 - val_loss: 1.6478 - val_accuracy: 0.4370
# Epoch 7/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.2202 - accuracy: 0.5653 - val_loss: 1.6496 - val_accuracy: 0.4326
# Epoch 8/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.1860 - accuracy: 0.5769 - val_loss: 1.7373 - val_accuracy: 0.4092
# Epoch 9/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.1618 - accuracy: 0.5844 - val_loss: 1.7027 - val_accuracy: 0.4330
# Epoch 10/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 1.1442 - accuracy: 0.5908 - val_loss: 1.6373 - val_accuracy: 0.4358
# Epoch 11/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.1251 - accuracy: 0.5976 - val_loss: 1.5343 - val_accuracy: 0.4682
# Epoch 12/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.0999 - accuracy: 0.6059 - val_loss: 1.5990 - val_accuracy: 0.4490
# Epoch 13/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.0824 - accuracy: 0.6136 - val_loss: 1.5609 - val_accuracy: 0.4630
# Epoch 14/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.0633 - accuracy: 0.6188 - val_loss: 1.6464 - val_accuracy: 0.4449
# Epoch 15/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.0392 - accuracy: 0.6261 - val_loss: 1.6146 - val_accuracy: 0.4483
# Epoch 16/50
# 50000/50000 [==============================] - 6s 115us/step - loss: 1.0293 - accuracy: 0.6324 - val_loss: 1.7127 - val_accuracy: 0.4381
# Epoch 17/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.0102 - accuracy: 0.6373 - val_loss: 1.7214 - val_accuracy: 0.4340
# Epoch 18/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.9920 - accuracy: 0.6459 - val_loss: 1.8222 - val_accuracy: 0.4120
# Epoch 19/50
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.9741 - accuracy: 0.6508 - val_loss: 1.6077 - val_accuracy: 0.4595
# Epoch 20/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.9502 - accuracy: 0.6585 - val_loss: 1.5970 - val_accuracy: 0.4764
# Epoch 21/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.9442 - accuracy: 0.6626 - val_loss: 1.7184 - val_accuracy: 0.4340
# Epoch 22/50
# 50000/50000 [==============================] - 6s 112us/step - loss: 0.9259 - accuracy: 0.6685 - val_loss: 1.7319 - val_accuracy: 0.4464
# Epoch 23/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.9026 - accuracy: 0.6792 - val_loss: 1.5884 - val_accuracy: 0.4719
# Epoch 24/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.8855 - accuracy: 0.6848 - val_loss: 1.7200 - val_accuracy: 0.4662
# Epoch 25/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 0.8644 - accuracy: 0.6892 - val_loss: 1.8440 - val_accuracy: 0.4297
# Epoch 26/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.8564 - accuracy: 0.6934 - val_loss: 1.9761 - val_accuracy: 0.4268
# Epoch 27/50
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.8440 - accuracy: 0.6977 - val_loss: 1.7759 - val_accuracy: 0.4555
# Epoch 28/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.8418 - accuracy: 0.6973 - val_loss: 1.8592 - val_accuracy: 0.4199
# Epoch 29/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.8210 - accuracy: 0.7059 - val_loss: 1.7347 - val_accuracy: 0.4686
# Epoch 30/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 0.8084 - accuracy: 0.7084 - val_loss: 1.9411 - val_accuracy: 0.4436
# Epoch 31/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.7911 - accuracy: 0.7161 - val_loss: 1.9236 - val_accuracy: 0.4265
# Epoch 32/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.7754 - accuracy: 0.7209 - val_loss: 1.9772 - val_accuracy: 0.4369
# Epoch 33/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.7639 - accuracy: 0.7229 - val_loss: 1.9214 - val_accuracy: 0.4322
# Epoch 34/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.7467 - accuracy: 0.7310 - val_loss: 2.1107 - val_accuracy: 0.4306
# Epoch 35/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.7477 - accuracy: 0.7305 - val_loss: 1.8745 - val_accuracy: 0.4539
# Epoch 36/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.7214 - accuracy: 0.7394 - val_loss: 2.1933 - val_accuracy: 0.4026
# Epoch 37/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.7102 - accuracy: 0.7455 - val_loss: 1.9757 - val_accuracy: 0.4443
# Epoch 38/50
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.6891 - accuracy: 0.7531 - val_loss: 1.9134 - val_accuracy: 0.4430
# Epoch 39/50
# 50000/50000 [==============================] - 6s 128us/step - loss: 0.6921 - accuracy: 0.7515 - val_loss: 1.8560 - val_accuracy: 0.4742
# Epoch 40/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.6710 - accuracy: 0.7572 - val_loss: 1.9240 - val_accuracy: 0.4551
# Epoch 41/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 0.6582 - accuracy: 0.7615 - val_loss: 1.9825 - val_accuracy: 0.4502
# Epoch 42/50
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.6508 - accuracy: 0.7652 - val_loss: 2.3079 - val_accuracy: 0.4357
# Epoch 43/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 0.6426 - accuracy: 0.7677 - val_loss: 2.1577 - val_accuracy: 0.4385
# Epoch 44/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 0.6367 - accuracy: 0.7716 - val_loss: 2.2186 - val_accuracy: 0.4398
# Epoch 45/50
# 50000/50000 [==============================] - 6s 118us/step - loss: 0.6349 - accuracy: 0.7697 - val_loss: 2.0990 - val_accuracy: 0.4510
# Epoch 46/50
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.6202 - accuracy: 0.7740 - val_loss: 2.2293 - val_accuracy: 0.4413
# Epoch 47/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.6032 - accuracy: 0.7819 - val_loss: 2.2145 - val_accuracy: 0.4431
# Epoch 48/50
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.5922 - accuracy: 0.7859 - val_loss: 2.1385 - val_accuracy: 0.4563
# Epoch 49/50
# 50000/50000 [==============================] - 7s 142us/step - loss: 0.5823 - accuracy: 0.7891 - val_loss: 2.3537 - val_accuracy: 0.4415
# Epoch 50/50
# 50000/50000 [==============================] - 7s 150us/step - loss: 0.5759 - accuracy: 0.7921 - val_loss: 2.3733 - val_accuracy: 0.4575

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

"""
Plot results
"""
plt.style.use('ggplot')
color_bar = ['r', 'b']

plt.figure(figsize=(20, 15))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(20, 15))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-10cad72524b6> in <module>
#      10 plt.figure(figsize=(20, 15))
#      11 for i, cond in enumerate(results.keys()):
# ---> 12     plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
#      13     plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
#      14 plt.title("Loss")
#
# IndexError: list index out of range
