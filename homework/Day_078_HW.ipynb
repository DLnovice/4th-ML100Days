# %% [markdown]
# ## Work
# 1. 請嘗試將 preproc_x 替換成以每筆資料的 min/max 進行標準化至 -1 ~ 1 間，再進行訓練
# 2. 請嘗試將 mlp 疊更深 (e.g 5~10 層)，進行訓練後觀察 learning curve 的走勢
# 3. (optional) 請改用 GPU 進行訓練 (如果你有 GPU 的話)，比較使用 CPU 與 GPU 的訓練速度

# %%
## 
"""
Your code here (optional)
確認硬體資源
"""
# Out:
# '\nYour code here (optional)\n確認硬體資源\n'

# %%
import os
import keras

# 請嘗試設定 GPU：os.environ
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape(len(x), -1)
        x = (x - x.min(axis=0)) / (x.max(axis=0) - x.min(axis=0)) * 2 - 1
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
## 建立你的神經網路

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128, 64, 32]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# hidden_layer5 (Dense)        (None, 32)                2080
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 1,748,266
# Trainable params: 1,748,266
# Non-trainable params: 0
# _________________________________________________________________

# %%
## 超參數設定
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 256

# %%
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

# %%
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.7192 - accuracy: 0.3912 - val_loss: 1.5450 - val_accuracy: 0.4551
# Epoch 2/100
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4792 - accuracy: 0.4770 - val_loss: 1.4648 - val_accuracy: 0.4825
# Epoch 3/100
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.3613 - accuracy: 0.5213 - val_loss: 1.4142 - val_accuracy: 0.5014
# Epoch 4/100
# 50000/50000 [==============================] - 3s 59us/step - loss: 1.2700 - accuracy: 0.5526 - val_loss: 1.3960 - val_accuracy: 0.5155
# Epoch 5/100
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.1824 - accuracy: 0.5831 - val_loss: 1.3783 - val_accuracy: 0.5149
# Epoch 6/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.1063 - accuracy: 0.6121 - val_loss: 1.3572 - val_accuracy: 0.5274
# Epoch 7/100
# 50000/50000 [==============================] - 4s 72us/step - loss: 1.0231 - accuracy: 0.6420 - val_loss: 1.3637 - val_accuracy: 0.5342
# Epoch 8/100
# 50000/50000 [==============================] - 4s 77us/step - loss: 0.9507 - accuracy: 0.6632 - val_loss: 1.4186 - val_accuracy: 0.5301
# Epoch 9/100
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.8797 - accuracy: 0.6864 - val_loss: 1.3923 - val_accuracy: 0.5384
# Epoch 10/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.8197 - accuracy: 0.7112 - val_loss: 1.4608 - val_accuracy: 0.5358
# Epoch 11/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.7523 - accuracy: 0.7320 - val_loss: 1.5159 - val_accuracy: 0.5381
# Epoch 12/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.6888 - accuracy: 0.7565 - val_loss: 1.5783 - val_accuracy: 0.5309
# Epoch 13/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.6307 - accuracy: 0.7769 - val_loss: 1.7259 - val_accuracy: 0.5281
# Epoch 14/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.5688 - accuracy: 0.7985 - val_loss: 1.7644 - val_accuracy: 0.5222
# Epoch 15/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.5236 - accuracy: 0.8148 - val_loss: 1.8220 - val_accuracy: 0.5290
# Epoch 16/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.4875 - accuracy: 0.8275 - val_loss: 1.9065 - val_accuracy: 0.5365
# Epoch 17/100
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4340 - accuracy: 0.8487 - val_loss: 1.9875 - val_accuracy: 0.5343
# Epoch 18/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.4071 - accuracy: 0.8565 - val_loss: 2.1335 - val_accuracy: 0.5323
# Epoch 19/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.3671 - accuracy: 0.8711 - val_loss: 2.1882 - val_accuracy: 0.5283
# Epoch 20/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.3512 - accuracy: 0.8776 - val_loss: 2.2562 - val_accuracy: 0.5231
# Epoch 21/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.3212 - accuracy: 0.8869 - val_loss: 2.3710 - val_accuracy: 0.5301
# Epoch 22/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.2993 - accuracy: 0.8958 - val_loss: 2.4137 - val_accuracy: 0.5310
# Epoch 23/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.2795 - accuracy: 0.9018 - val_loss: 2.5213 - val_accuracy: 0.5201
# Epoch 24/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.2738 - accuracy: 0.9039 - val_loss: 2.6391 - val_accuracy: 0.5298
# Epoch 25/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.2585 - accuracy: 0.9100 - val_loss: 2.6777 - val_accuracy: 0.5319
# Epoch 26/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.2167 - accuracy: 0.9248 - val_loss: 2.9034 - val_accuracy: 0.5349
# Epoch 27/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.2241 - accuracy: 0.9219 - val_loss: 2.8729 - val_accuracy: 0.5242
# Epoch 28/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.2117 - accuracy: 0.9261 - val_loss: 2.8946 - val_accuracy: 0.5216
# Epoch 29/100
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.1982 - accuracy: 0.9313 - val_loss: 3.0442 - val_accuracy: 0.5230
# Epoch 30/100
# 50000/50000 [==============================] - 4s 75us/step - loss: 0.2057 - accuracy: 0.9290 - val_loss: 3.0696 - val_accuracy: 0.5234
# Epoch 31/100
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.1932 - accuracy: 0.9345 - val_loss: 3.0478 - val_accuracy: 0.5322
# Epoch 32/100
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.1577 - accuracy: 0.9462 - val_loss: 3.2643 - val_accuracy: 0.5356
# Epoch 33/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1735 - accuracy: 0.9401 - val_loss: 3.1975 - val_accuracy: 0.5293
# Epoch 34/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1667 - accuracy: 0.9434 - val_loss: 3.3248 - val_accuracy: 0.5274
# Epoch 35/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1671 - accuracy: 0.9427 - val_loss: 3.3501 - val_accuracy: 0.5274
# Epoch 36/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1413 - accuracy: 0.9516 - val_loss: 3.5227 - val_accuracy: 0.5280
# Epoch 37/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.1679 - accuracy: 0.9417 - val_loss: 3.4529 - val_accuracy: 0.5313
# Epoch 38/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1606 - accuracy: 0.9450 - val_loss: 3.4516 - val_accuracy: 0.5258
# Epoch 39/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.1616 - accuracy: 0.9454 - val_loss: 3.4526 - val_accuracy: 0.5290
# Epoch 40/100
# 50000/50000 [==============================] - 4s 72us/step - loss: 0.1080 - accuracy: 0.9633 - val_loss: 3.6897 - val_accuracy: 0.5356
# Epoch 41/100
# 50000/50000 [==============================] - 4s 75us/step - loss: 0.1246 - accuracy: 0.9566 - val_loss: 3.8526 - val_accuracy: 0.5278
# Epoch 42/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.1408 - accuracy: 0.9524 - val_loss: 3.6232 - val_accuracy: 0.5275
# Epoch 43/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1483 - accuracy: 0.9496 - val_loss: 3.6481 - val_accuracy: 0.5230
# Epoch 44/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.1225 - accuracy: 0.9584 - val_loss: 3.6564 - val_accuracy: 0.5258
# Epoch 45/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.1201 - accuracy: 0.9591 - val_loss: 3.7269 - val_accuracy: 0.5198
# Epoch 46/100
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.1332 - accuracy: 0.9554 - val_loss: 3.7206 - val_accuracy: 0.5260
# Epoch 47/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1187 - accuracy: 0.9595 - val_loss: 3.8548 - val_accuracy: 0.5238
# Epoch 48/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.1333 - accuracy: 0.9546 - val_loss: 3.9064 - val_accuracy: 0.5276
# Epoch 49/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1077 - accuracy: 0.9642 - val_loss: 3.8778 - val_accuracy: 0.5284
# Epoch 50/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1053 - accuracy: 0.9646 - val_loss: 3.8672 - val_accuracy: 0.5302
# Epoch 51/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.1082 - accuracy: 0.9645 - val_loss: 4.0146 - val_accuracy: 0.5264
# Epoch 52/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.1191 - accuracy: 0.9596 - val_loss: 3.8663 - val_accuracy: 0.5336
# Epoch 53/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1045 - accuracy: 0.9642 - val_loss: 4.0087 - val_accuracy: 0.5283
# Epoch 54/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1210 - accuracy: 0.9592 - val_loss: 3.9827 - val_accuracy: 0.5263
# Epoch 55/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.1048 - accuracy: 0.9656 - val_loss: 4.1372 - val_accuracy: 0.5318
# Epoch 56/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.0979 - accuracy: 0.9676 - val_loss: 4.2600 - val_accuracy: 0.5225
# Epoch 57/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.1156 - accuracy: 0.9617 - val_loss: 4.1382 - val_accuracy: 0.5282
# Epoch 58/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.0971 - accuracy: 0.9682 - val_loss: 4.0659 - val_accuracy: 0.5311
# Epoch 59/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0992 - accuracy: 0.9672 - val_loss: 4.1877 - val_accuracy: 0.5267
# Epoch 60/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.0988 - accuracy: 0.9673 - val_loss: 4.1448 - val_accuracy: 0.5306
# Epoch 61/100
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.0782 - accuracy: 0.9751 - val_loss: 4.2149 - val_accuracy: 0.5333
# Epoch 62/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.0929 - accuracy: 0.9697 - val_loss: 4.2996 - val_accuracy: 0.5322
# Epoch 63/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0988 - accuracy: 0.9671 - val_loss: 4.2002 - val_accuracy: 0.5342
# Epoch 64/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.1062 - accuracy: 0.9654 - val_loss: 4.2062 - val_accuracy: 0.5272
# Epoch 65/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.0868 - accuracy: 0.9714 - val_loss: 4.2449 - val_accuracy: 0.5315
# Epoch 66/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.0821 - accuracy: 0.9728 - val_loss: 4.3471 - val_accuracy: 0.5312
# Epoch 67/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.0846 - accuracy: 0.9721 - val_loss: 4.2865 - val_accuracy: 0.5254
# Epoch 68/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0985 - accuracy: 0.9671 - val_loss: 4.3687 - val_accuracy: 0.5352
# Epoch 69/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0909 - accuracy: 0.9695 - val_loss: 4.3187 - val_accuracy: 0.5319
# Epoch 70/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0734 - accuracy: 0.9761 - val_loss: 4.4131 - val_accuracy: 0.5260
# Epoch 71/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.0798 - accuracy: 0.9730 - val_loss: 4.3580 - val_accuracy: 0.5334
# Epoch 72/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.0745 - accuracy: 0.9757 - val_loss: 4.4211 - val_accuracy: 0.5344
# Epoch 73/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.0932 - accuracy: 0.9694 - val_loss: 4.4700 - val_accuracy: 0.5274
# Epoch 74/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.1017 - accuracy: 0.9673 - val_loss: 4.2507 - val_accuracy: 0.5295
# Epoch 75/100
# 50000/50000 [==============================] - 4s 71us/step - loss: 0.0734 - accuracy: 0.9769 - val_loss: 4.3608 - val_accuracy: 0.5336
# Epoch 76/100
# 50000/50000 [==============================] - 3s 69us/step - loss: 0.0706 - accuracy: 0.9763 - val_loss: 4.3940 - val_accuracy: 0.5323
# Epoch 77/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0775 - accuracy: 0.9749 - val_loss: 4.4174 - val_accuracy: 0.5309
# Epoch 78/100
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.0884 - accuracy: 0.9718 - val_loss: 4.3870 - val_accuracy: 0.5253
# Epoch 79/100
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.0788 - accuracy: 0.9747 - val_loss: 4.3880 - val_accuracy: 0.5295
# Epoch 80/100
# 50000/50000 [==============================] - 4s 73us/step - loss: 0.0668 - accuracy: 0.9778 - val_loss: 4.4888 - val_accuracy: 0.5268
# Epoch 81/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.0800 - accuracy: 0.9739 - val_loss: 4.5166 - val_accuracy: 0.5330
# Epoch 82/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0789 - accuracy: 0.9744 - val_loss: 4.4453 - val_accuracy: 0.5313
# Epoch 83/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0610 - accuracy: 0.9805 - val_loss: 4.6623 - val_accuracy: 0.5237
# Epoch 84/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.0794 - accuracy: 0.9740 - val_loss: 4.4366 - val_accuracy: 0.5276
# Epoch 85/100
# 50000/50000 [==============================] - 4s 76us/step - loss: 0.0843 - accuracy: 0.9730 - val_loss: 4.4727 - val_accuracy: 0.5256
# Epoch 86/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0863 - accuracy: 0.9721 - val_loss: 4.4178 - val_accuracy: 0.5266
# Epoch 87/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0668 - accuracy: 0.9785 - val_loss: 4.6829 - val_accuracy: 0.5247
# Epoch 88/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.0567 - accuracy: 0.9816 - val_loss: 4.6727 - val_accuracy: 0.5243
# Epoch 89/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0558 - accuracy: 0.9817 - val_loss: 4.6705 - val_accuracy: 0.5306
# Epoch 90/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.0992 - accuracy: 0.9701 - val_loss: 4.2963 - val_accuracy: 0.5333
# Epoch 91/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.0699 - accuracy: 0.9782 - val_loss: 4.3793 - val_accuracy: 0.5404
# Epoch 92/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0541 - accuracy: 0.9829 - val_loss: 4.5841 - val_accuracy: 0.5326
# Epoch 93/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.0563 - accuracy: 0.9816 - val_loss: 4.6102 - val_accuracy: 0.5294
# Epoch 94/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.0856 - accuracy: 0.9732 - val_loss: 4.5021 - val_accuracy: 0.5240
# Epoch 95/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.0656 - accuracy: 0.9775 - val_loss: 4.6712 - val_accuracy: 0.5325
# Epoch 96/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0582 - accuracy: 0.9815 - val_loss: 4.8788 - val_accuracy: 0.5257
# Epoch 97/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0697 - accuracy: 0.9773 - val_loss: 4.8262 - val_accuracy: 0.5274
# Epoch 98/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0536 - accuracy: 0.9825 - val_loss: 4.7782 - val_accuracy: 0.5251
# Epoch 99/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.0848 - accuracy: 0.9745 - val_loss: 4.5476 - val_accuracy: 0.5262
# Epoch 100/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.0573 - accuracy: 0.9818 - val_loss: 4.7354 - val_accuracy: 0.5294

# %%
import matplotlib.pyplot as plt


train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
