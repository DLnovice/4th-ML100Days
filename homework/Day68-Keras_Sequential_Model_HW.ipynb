# %% [markdown]
# # 作業目標:
#
#     了解keras 模型架構
#
#
# # 作業重點:
#
#     請修改input shape: (Conv2D(64, (3, 3))的設定, 新增一層 Dense 並觀看 model.summary 的輸出

# %%
# 載入必須使用的 Library
import keras
from keras.datasets import cifar10
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
# Out:
# Using TensorFlow backend.

# %%
num_classes = 10

# 轉換label 為OneHot Encoding
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
print('Shape of x_train:', x_train.shape)

# build our CNN model, 多加幾層
model = Sequential()
model.add(Conv2D(32, (3, 3), padding = 'same', input_shape = x_train.shape[1:]))
model.add(Conv2D(32, (3, 3), padding = 'same'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(4096))
model.add(Activation('relu'))
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
print(model.summary())
# Out:
# Shape of x_train: (50000, 32, 32, 3)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              33558528
# _________________________________________________________________
# activation_1 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                262208
# _________________________________________________________________
# activation_2 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 33,831,530
# Trainable params: 33,831,530
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# initiate Adam optimizer
opt = keras.optimizers.Adam()

# Let's train the model using Adam
model.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics = ['accuracy'])

model_history = model.fit(x_train, y_train, validation_split = 0.2, epochs = 10, batch_size = 128, verbose = 1)  

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose = 1)
print('Test accuracy:', scores[1])
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 27s 683us/step - loss: 2.3587 - accuracy: 0.1039 - val_loss: 2.3028 - val_accuracy: 0.0977
# Epoch 2/10
# 40000/40000 [==============================] - 24s 606us/step - loss: 2.3027 - accuracy: 0.0971 - val_loss: 2.3028 - val_accuracy: 0.0977
# Epoch 3/10
# 40000/40000 [==============================] - 25s 614us/step - loss: 2.3027 - accuracy: 0.1003 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 4/10
# 40000/40000 [==============================] - 24s 607us/step - loss: 2.3027 - accuracy: 0.0979 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 5/10
# 40000/40000 [==============================] - 24s 607us/step - loss: 2.3027 - accuracy: 0.0999 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 6/10
# 40000/40000 [==============================] - 24s 600us/step - loss: 2.3027 - accuracy: 0.0984 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 7/10
# 40000/40000 [==============================] - 24s 588us/step - loss: 2.3027 - accuracy: 0.0993 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 8/10
# 40000/40000 [==============================] - 24s 592us/step - loss: 2.3027 - accuracy: 0.1002 - val_loss: 2.3027 - val_accuracy: 0.0977
# Epoch 9/10
# 40000/40000 [==============================] - 24s 589us/step - loss: 2.3027 - accuracy: 0.1001 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 10/10
# 31360/40000 [======================>.......] - ETA: 4s - loss: 2.3027 - accuracy: 0.0997
